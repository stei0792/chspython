# %% [markdown]
# # Urea Model Average Case

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
data = pd.read_csv("C:/Users/msteinme/Documents/ureamarchupdateavg2.csv")
df_96on = data[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea']][0:1056]
df_96on.tail()
# Out:
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea
# 1051  2/26/2016  34.58  359.50          50.45          50.45   265
# 1052   3/4/2016  37.75  358.25          51.00          51.00   270
# 1053  3/11/2016  40.09  365.00          51.50          51.50   274
# 1054  3/18/2016  41.14  371.75          52.20          52.20   265
# 1055  3/25/2016  40.63  374.50          51.75          51.75   255

# %%
from datetime import datetime
df_96on['Date'] = pd.to_datetime(df_96on['Date'])
date = df_96on['Date']
df_96on.dtypes
# Out:
# Date             datetime64[ns]
# Crude                   float64
# Corn                    float64
# Coal_RDF(MLR)           float64
# Coal_RDF(RDF)           float64
# Urea                    float64
# dtype: object

# %%
df_96on.describe() #make sure both coals are the same
# Out:
#              Crude         Corn  Coal_RDF(MLR)  Coal_RDF(RDF)         Urea
# count  1056.000000  1056.000000    1056.000000    1056.000000  1056.000000
# mean     54.851648   361.660275      58.312026      58.312026   260.121212
# std      31.319022   157.085607      33.658418      33.658418   135.997458
# min      11.260000   182.500000      20.900000      20.900000    83.000000
# 25%      26.402500   231.000000      27.425593      27.425593   150.750000
# 50%      49.655000   322.750000      51.925000      51.925000   240.000000
# 75%      82.082500   425.562500      80.175000      80.175000   335.000000
# max     145.860000   809.250000     192.500000     192.500000   825.000000

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
#fit a OLS model with all, see how R^2 changes
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']]
Y = df_96on[['Urea']]
X= sm.add_constant(X)
est= sm.OLS(Y,X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Urea   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     1599.
# Date:                Mon, 04 Apr 2016   Prob (F-statistic):               0.00
# Time:                        08:10:39   Log-Likelihood:                -5779.9
# No. Observations:                1056   AIC:                         1.157e+04
# Df Residuals:                    1052   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
X = df_96on[['Crude','Corn','Coal_RDF(RDF)']]
Y = df_96on[['Urea']]
X= sm.add_constant(X)
est= sm.OLS(Y,X).fit()
est.summary()
#should be the same as the above one
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Urea   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     1599.
# Date:                Mon, 04 Apr 2016   Prob (F-statistic):               0.00
# Time:                        08:10:48   Log-Likelihood:                -5779.9
# No. Observations:                1056   AIC:                         1.157e+04
# Df Residuals:                    1052   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
# Out:
# MSE train: 256.993, test: 1274.824
# R^2 train: 0.987, test: 0.917
# [ 0.57787125  0.09728979  0.32483896]

# %%
#comparing the different models
urea_predicted3 = forest.predict(X)
urea_predicted3 = pd.DataFrame(urea_predicted3)
df_96on['Urea_Pred_RDF(MLR)'] = urea_predicted3
rdf_error3 = (abs(df_96on['Urea_Pred_RDF(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error3

urea_predicted4 = forest.predict(X)
urea_predicted4 = pd.DataFrame(urea_predicted4)
df_96on['Urea_Pred_RDF(RDF)'] = urea_predicted4
rdf_error4 = (abs(df_96on['Urea_Pred_RDF(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error4

mlrtop3_predicted = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(MLR)']*1.6182) 
df_96on['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted
mlrtop3_error = (abs(df_96on['Urea_Pred_MLR(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(MLR)'] = mlrtop3_error

mlrtop3_predicted2 = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(RDF)']*1.6182) 
df_96on['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted2
mlrtop3_error2 = (abs(df_96on['Urea_Pred_MLR(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(RDF)'] = mlrtop3_error2

print("Average RDF(MLR) error is: %.3f" % (rdf_error3.mean())) 
print("Average RDF(RDF) error is: %.3f" % (rdf_error4.mean()))
print("Average MLR(MLR) Top3 error is: %.3f" % (mlrtop3_error.mean()))
print("Average MLR(RDF) Top3 error is: %.3f" % (mlrtop3_error2.mean()))

df_96on
# Out:
# Average RDF(MLR) error is: 5.287
# Average RDF(RDF) error is: 5.287
# Average MLR(MLR) Top3 error is: 16.762
# Average MLR(RDF) Top3 error is: 16.762
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  \
# 0    1996-01-05  19.65  369.75      25.358912      25.358912   220
# 1    1996-01-12  17.98  366.25      25.269689      25.269689   220
# 2    1996-01-19  18.25  365.00      29.070713      29.070713   218
# 3    1996-01-26  17.36  360.25      29.195096      29.195096   215
# 4    1996-02-02  17.38  370.50      32.105527      32.105527   205
# 5    1996-02-09  17.38  367.25      28.667889      28.667889   205
# 6    1996-02-16  18.40  382.75      28.169393      28.169393   210
# 7    1996-02-23  18.45  383.50      28.828182      28.828182   210
# 8    1996-03-01  18.62  386.75      27.863549      27.863549   210
# 9    1996-03-08  18.87  388.50      26.513218      26.513218   205
# 10   1996-03-15  20.08  383.25      27.863549      27.863549   205
# ...

# %%
newpred2 = data [['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']][1056:]
newpred = data [['Crude','Corn','Coal_RDF(MLR)']][1056:]
newpred3 = data[['Crude','Corn','Coal_RDF(RDF)']][1056:]

# %%
#new predictions
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)

newpred2 = np.array(newpred2)
newpred2 = pd.DataFrame(newpred2)
newpred2.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']
newpred_predicted = forest.predict(newpred)
df_new_pred = pd.DataFrame(newpred_predicted)
newpred2['Urea_Pred_RDF(MLR)'] = df_new_pred

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 255.162, test: 1274.665
# R^2 train: 0.987, test: 0.917
# [ 0.57042244  0.11044974  0.31912782]
#            Date    Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26    40.63    374.5        52.141       52.2996
# 1    2016-03-27    40.63    374.5        52.141       52.2996
# 2    2016-03-28    40.53    370.5        52.141        53.059
# 3    2016-03-29    39.51      373       53.0023       53.5602
# 4    2016-03-30    39.66      367       53.1493       53.7676
# 5    2016-03-31    39.36    351.5       53.1866       57.4817
# 6    2016-04-01    39.55  372.991        52.141       52.2996
# 7    2016-04-02    39.52  372.974       52.1103       52.2996
# 8    2016-04-03    39.49  372.957       52.1103       52.2996
# 9    2016-04-04    39.46   372.94       52.1103       52.2996
# 10   2016-04-05    39.43  372.922       52.1103       52.2996
# 11   2016-04-06     39.4  372.905       52.1103       52.3227
# ...

# %%
X = df_96on[['Crude','Corn','Coal_RDF(RDF)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
newpred_predicted2 = forest.predict(newpred3)
df_new_pred2 = pd.DataFrame(newpred_predicted2)
newpred2['Urea_Pred_RDF(RDF)'] = df_new_pred2

mlrtop3_predicted5 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(MLR)']*1.6182) 
newpred2['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted5

mlrtop3_predicted6 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(RDF)']*1.6182) 
newpred2['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted6

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 257.664, test: 1348.894
# R^2 train: 0.987, test: 0.912
# [ 0.57670123  0.09605306  0.32724571]
#            Date    Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26    40.63    374.5        52.141       52.2996
# 1    2016-03-27    40.63    374.5        52.141       52.2996
# 2    2016-03-28    40.53    370.5        52.141        53.059
# 3    2016-03-29    39.51      373       53.0023       53.5602
# 4    2016-03-30    39.66      367       53.1493       53.7676
# 5    2016-03-31    39.36    351.5       53.1866       57.4817
# 6    2016-04-01    39.55  372.991        52.141       52.2996
# 7    2016-04-02    39.52  372.974       52.1103       52.2996
# 8    2016-04-03    39.49  372.957       52.1103       52.2996
# 9    2016-04-04    39.46   372.94       52.1103       52.2996
# 10   2016-04-05    39.43  372.922       52.1103       52.2996
# 11   2016-04-06     39.4  372.905       52.1103       52.3227
# ...

# %%
frames = [df_96on,newpred2]
combined = pd.concat(frames)
combined
# Out:
#      Coal_RDF(MLR) Coal_RDF(RDF)     Corn    Crude       Date  MLR_Error(MLR)  \
# 0          25.3589       25.3589   369.75    19.65 1996-01-05       31.900057
# 1          25.2697       25.2697   366.25    17.98 1996-01-12       33.452854
# 2          29.0707       29.0707      365    18.25 1996-01-19       29.900320
# 3          29.1951       29.1951   360.25    17.36 1996-01-26       29.836261
# 4          32.1055       32.1055    370.5    17.38 1996-02-02       23.367129
# 5          28.6679       28.6679   367.25    17.38 1996-02-09       26.313098
# 6          28.1694       28.1694   382.75     18.4 1996-02-16       26.567275
# 7          28.8282       28.8282    383.5    18.45 1996-02-23       25.967943
# 8          27.8635       27.8635   386.75    18.62 1996-03-01       26.350656
# 9          26.5132       26.5132    388.5    18.87 1996-03-08       25.293638
# 10         27.8635       27.8635   383.25    20.08 1996-03-15       23.628148
# ...

# %%
combined.to_csv("C:/Users/msteinme/Documents/ureaavgmarch2.csv")

# %%
combined = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']]
combined = np.array(combined)
combined = pd.DataFrame(combined)
combined.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
combined
# Out:
#                      Date    Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 0     1996-01-05 00:00:00    19.65   369.75       25.3589       25.3589  220
# 1     1996-01-12 00:00:00    17.98   366.25       25.2697       25.2697  220
# 2     1996-01-19 00:00:00    18.25      365       29.0707       29.0707  218
# 3     1996-01-26 00:00:00    17.36   360.25       29.1951       29.1951  215
# 4     1996-02-02 00:00:00    17.38    370.5       32.1055       32.1055  205
# 5     1996-02-09 00:00:00    17.38   367.25       28.6679       28.6679  205
# 6     1996-02-16 00:00:00     18.4   382.75       28.1694       28.1694  210
# 7     1996-02-23 00:00:00    18.45    383.5       28.8282       28.8282  210
# 8     1996-03-01 00:00:00    18.62   386.75       27.8635       27.8635  210
# 9     1996-03-08 00:00:00    18.87    388.5       26.5132       26.5132  205
# 10    1996-03-15 00:00:00    20.08   383.25       27.8635       27.8635  205
# ...

# %%
#monthly predictions remember 2 months in future so jan96->mar96
mar_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][0:4]
apr_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][4:8]
may_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][8:13]
jun_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][13:17]
jul_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][17:22]
aug_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][22:26]
sep_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][26:30]
oct_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][30:35]
nov_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][35:39]
dec_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][39:43]
jan_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][43:48]
feb_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][48:52]
mar_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][52:57]
apr_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][57:61]
may_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][61:65]
jun_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][65:69]
jul_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][69:74]
aug_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][74:78]
sep_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][78:82]
oct_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][82:87]
nov_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][87:91]
dec_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][91:96]
jan_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][96:100]
feb_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][100:104]
mar_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][104:109]
apr_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][109:113]
may_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][113:117]
jun_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][117:121]
jul_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][121:126]
aug_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][126:130]
sep_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][130:135]
oct_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][135:139]
nov_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][139:143]
dec_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][143:148]
jan_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][148:152]
feb_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][152:156]
mar_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][156:161]
apr_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][161:165]
may_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][165:169]
jun_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][169:174]
jul_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][174:178]
aug_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][178:182]
sep_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][182:187]
oct_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][187:191]
nov_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][191:195]
dec_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][195:200]
jan_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][200:204]
feb_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][204:209]
mar_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][209:213]
apr_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][213:217]
may_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][217:222]
jun_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][222:226]
jul_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][226:230]
aug_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][230:235]
sep_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][235:239]
oct_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][239:243]
nov_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][243:248]
dec_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][248:252]
jan_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][252:256]
feb_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][256:261]
mar_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][261:265]
apr_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][265:269]
may_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][269:274]
jun_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][274:278]
jul_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][278:282]
aug_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][282:287]
sep_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][287:291]
oct_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][291:296]
nov_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][296:300]
dec_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][300:304]
jan_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][304:309]
feb_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][309:313]
mar_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][313:317]
apr_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][317:321]
may_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][321:326]
jun_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][326:330]
jul_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][330:335]
aug_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][335:339]
sep_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][339:343]
oct_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][343:348]
nov_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][348:352]
dec_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][352:356]
jan_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][356:361]
feb_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][361:365]
mar_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][365:370]
apr_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][370:374]
may_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][374:378]
jun_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][378:382]
jul_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][382:387]
aug_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][387:391]
sep_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][391:395]
oct_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][395:400]
nov_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][400:404]
dec_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][404:409]
jan_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][409:413]
feb_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][413:417]
mar_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][417:422]
apr_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][422:426]
may_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][426:430]
jun_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][430:435]
jul_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][435:439]
aug_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][439:443]
sep_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][443:448]
oct_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][448:452]
nov_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][452:456]
dec_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][456:461]
jan_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][461:465]
feb_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][465:470]
mar_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][470:474]
apr_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][474:478]
may_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][478:482]
jun_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][482:487]
jul_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][487:491]
aug_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][491:495]
sep_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][495:500]
oct_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][500:504]
nov_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][504:509]
dec_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][509:513]
jan_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][513:517]
feb_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][517:522]
mar_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][522:526]
apr_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][526:530]
may_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][530:535]
jun_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][535:539]
jul_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][539:543]
aug_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][543:548]
sep_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][548:552]
oct_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][552:556]
nov_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][556:561]
dec_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][561:565]
jan_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][565:569]
feb_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][569:574]
mar_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][574:578]
apr_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][578:582]
may_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][582:587]
jun_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][587:591]
jul_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][591:595]
aug_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][595:600]
sep_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][600:604]
oct_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][604:609]
nov_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][609:613]
dec_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][613:617]
jan_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][617:622]
feb_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][622:626]
mar_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][626:630]
apr_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][630:635]
may_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][635:639]
jun_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][639:643]
jul_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][643:648]
aug_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][648:652]
sep_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][652:656]
oct_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][656:661]
nov_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][661:665]
dec_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][665:670]
jan_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][670:674]
feb_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][674:678]
mar_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][678:683]
apr_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][683:687]
may_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][687:691]
jun_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][691:695]
jul_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][695:700]
aug_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][700:704]
sep_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][704:709]
oct_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][709:713]
nov_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][713:717]
dec_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][717:722]
jan_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][722:726]
feb_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][726:730]
mar_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][730:735]
apr_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][735:739]
may_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][739:743]
jun_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][743:748]
jul_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][748:752]
aug_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][752:756]
sep_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][756:761]
oct_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][761:765]
nov_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][765:769]
dec_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][769:774]
jan_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][774:778]
feb_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][778:783]
mar_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][783:787]
apr_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][787:791]
may_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][791:795]
jun_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][795:800]
jul_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][800:804]
aug_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][804:808]
sep_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][808:813]
oct_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][813:817]
nov_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][817:822]
dec_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][822:826]
jan_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][826:830]
feb_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][830:835]
mar_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][835:839]
apr_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][839:843]
may_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][843:848]
jun_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][848:852]
jul_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][852:856]
aug_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][856:861]
sep_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][861:865]
oct_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][865:870]
nov_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][870:874]
dec_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][874:878]
jan_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][878:883]
feb_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][883:887]
mar_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][887:891]
apr_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][891:895]
may_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][895:900]
jun_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][900:904]
jul_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][904:909]
aug_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][909:913]
sep_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][913:917]
oct_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][917:922]
nov_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][922:926]
dec_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][926:930]
jan_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][930:935]
feb_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][935:939]
mar_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][939:944]
apr_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][944:948]
may_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][948:952]
jun_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][952:956]
jul_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][956:961]
aug_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][961:965]
sep_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][965:969]
oct_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][969:974]
nov_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][974:978]
dec_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][978:983]
jan_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][983:987]
feb_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][987:991]
mar_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][991:996]
apr_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][996:1000]
may_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1000:1004]
jun_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1004:1008]
jul_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1008:1013]
aug_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1013:1017]
sep_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1017:1022]
oct_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1022:1026]
nov_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1026:1030]
dec_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1030:1035]
jan_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1035:1039]
feb_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1039:1043]
mar_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1043:1048]
apr_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1048:1052]
may_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1052:1056]
apr_96
# Out:
#                   Date  Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 4  1996-02-02 00:00:00  17.38   370.5       32.1055       32.1055  205
# 5  1996-02-09 00:00:00  17.38  367.25       28.6679       28.6679  205
# 6  1996-02-16 00:00:00   18.4  382.75       28.1694       28.1694  210
# 7  1996-02-23 00:00:00  18.45   383.5       28.8282       28.8282  210
#
#   Urea_Pred_MLR(MLR) Urea_Pred_MLR(RDF) Urea_Pred_RDF(MLR) Urea_Pred_RDF(RDF)
# 4            157.097            157.097             203.37             203.37
# 5            151.058            151.058            204.016            204.016
# 6            154.209            154.209            201.016            201.016
# 7            155.467            155.467            203.598            203.598

# %%
# predicted chunk
jun_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1062:1092]
jul_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1092:1123]
aug_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1123:1153]
sep_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1153:1184]
oct_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1184:1215]
nov_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1215:1245]
dec_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1245:1276]
jan_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1276:1306]
feb_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1306:1337]
mar_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1337:1368]
apr_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1368:1396]
may_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1396:1427]
jun_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1427:1457]
jul_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1457:1488]
aug_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1488:1518]
sep_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1518:1549]
oct_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1549:1580]
nov_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1580:1610]
dec_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1610:1641]
jan_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1641:1671]
feb_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1671:1702]
mar_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1702:1733]
apr_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1733:1761]
may_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1761:1792]
jun_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1792:1822]
jul_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1822:1853]
aug_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1853:1883]
sep_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1883:1914]
oct_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1914:1945]
nov_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1945:1975]
dec_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1975:2006]
jan_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2006:2036]
feb_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2036:2067]
mar_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2067:2098]
apr_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2098:2126]
may_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2126:2157]
jun_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2157:2187]
jul_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2187:2218]
aug_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2218:2248]
sep_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2248:2279]
oct_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2279:2310]
nov_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2310:2340]
dec_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2340:2371]
jan_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2371:2401]
feb_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2401:2432]
mar_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2432:2463]
apr_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2463:2492]
may_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2492:2523]
jun_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2523:2553]
jul_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2553:2584]
aug_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2584:2614]
sep_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2614:2645]
oct_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2645:2676]
nov_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2676:2706]
dec_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2706:2737]
jan_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2737:2767]
feb_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2767:2798]

# %%
mycolumns = ['Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
df = pd.DataFrame(columns=mycolumns)
rows = [mar_96[mycolumns].mean(),apr_96[mycolumns].mean(),may_96[mycolumns].mean(),jun_96[mycolumns].mean(),
        jul_96[mycolumns].mean(),aug_96[mycolumns].mean(),sep_96[mycolumns].mean(),oct_96[mycolumns].mean(),nov_96[mycolumns].mean(),dec_96[mycolumns].mean(),
        jan_97[mycolumns].mean(),feb_97[mycolumns].mean(),mar_97[mycolumns].mean(),apr_97[mycolumns].mean(),may_97[mycolumns].mean(),jun_97[mycolumns].mean(),
        jul_97[mycolumns].mean(),aug_97[mycolumns].mean(),sep_97[mycolumns].mean(),oct_97[mycolumns].mean(),nov_97[mycolumns].mean(),dec_97[mycolumns].mean(),
        jan_98[mycolumns].mean(),feb_98[mycolumns].mean(),mar_98[mycolumns].mean(),apr_98[mycolumns].mean(),may_98[mycolumns].mean(),jun_98[mycolumns].mean(),
        jul_98[mycolumns].mean(),aug_98[mycolumns].mean(),sep_98[mycolumns].mean(),oct_98[mycolumns].mean(),nov_98[mycolumns].mean(),dec_98[mycolumns].mean(),
        jan_99[mycolumns].mean(),feb_99[mycolumns].mean(),mar_99[mycolumns].mean(),apr_99[mycolumns].mean(),may_99[mycolumns].mean(),jun_99[mycolumns].mean(),
        jul_99[mycolumns].mean(),aug_99[mycolumns].mean(),sep_99[mycolumns].mean(),oct_99[mycolumns].mean(),nov_99[mycolumns].mean(),dec_99[mycolumns].mean(),
        jan_00[mycolumns].mean(),feb_00[mycolumns].mean(),mar_00[mycolumns].mean(),apr_00[mycolumns].mean(),may_00[mycolumns].mean(),jun_00[mycolumns].mean(),
        jul_00[mycolumns].mean(),aug_00[mycolumns].mean(),sep_00[mycolumns].mean(),oct_00[mycolumns].mean(),nov_00[mycolumns].mean(),dec_00[mycolumns].mean(),
        jan_01[mycolumns].mean(),feb_01[mycolumns].mean(),mar_01[mycolumns].mean(),apr_01[mycolumns].mean(),may_01[mycolumns].mean(),jun_01[mycolumns].mean(),
        jul_01[mycolumns].mean(),aug_01[mycolumns].mean(),sep_01[mycolumns].mean(),oct_01[mycolumns].mean(),nov_01[mycolumns].mean(),dec_01[mycolumns].mean(),
        jan_02[mycolumns].mean(),feb_02[mycolumns].mean(),mar_02[mycolumns].mean(),apr_02[mycolumns].mean(),may_02[mycolumns].mean(),jun_02[mycolumns].mean(),
        jul_02[mycolumns].mean(),aug_02[mycolumns].mean(),sep_02[mycolumns].mean(),oct_02[mycolumns].mean(),nov_02[mycolumns].mean(),dec_02[mycolumns].mean(),
        jan_03[mycolumns].mean(),feb_03[mycolumns].mean(),mar_03[mycolumns].mean(),apr_03[mycolumns].mean(),may_03[mycolumns].mean(),jun_03[mycolumns].mean(),
        jul_03[mycolumns].mean(),aug_03[mycolumns].mean(),sep_03[mycolumns].mean(),oct_03[mycolumns].mean(),nov_03[mycolumns].mean(),dec_03[mycolumns].mean(),
        jan_04[mycolumns].mean(),feb_04[mycolumns].mean(),mar_04[mycolumns].mean(),apr_04[mycolumns].mean(),may_04[mycolumns].mean(),jun_04[mycolumns].mean(),
        jul_04[mycolumns].mean(),aug_04[mycolumns].mean(),sep_04[mycolumns].mean(),oct_04[mycolumns].mean(),nov_04[mycolumns].mean(),dec_04[mycolumns].mean(),
        jan_05[mycolumns].mean(),feb_05[mycolumns].mean(),mar_05[mycolumns].mean(),apr_05[mycolumns].mean(),may_05[mycolumns].mean(),jun_05[mycolumns].mean(),
        jul_05[mycolumns].mean(),aug_05[mycolumns].mean(),sep_05[mycolumns].mean(),oct_05[mycolumns].mean(),nov_05[mycolumns].mean(),dec_05[mycolumns].mean(),
        jan_06[mycolumns].mean(),feb_06[mycolumns].mean(),mar_06[mycolumns].mean(),apr_06[mycolumns].mean(),may_06[mycolumns].mean(),jun_06[mycolumns].mean(),
        jul_06[mycolumns].mean(),aug_06[mycolumns].mean(),sep_06[mycolumns].mean(),oct_06[mycolumns].mean(),nov_06[mycolumns].mean(),dec_06[mycolumns].mean(),
        jan_07[mycolumns].mean(),feb_07[mycolumns].mean(),mar_07[mycolumns].mean(),apr_07[mycolumns].mean(),may_07[mycolumns].mean(),jun_07[mycolumns].mean(),
        jul_07[mycolumns].mean(),aug_07[mycolumns].mean(),sep_07[mycolumns].mean(),oct_07[mycolumns].mean(),nov_07[mycolumns].mean(),dec_07[mycolumns].mean(),
        jan_08[mycolumns].mean(),feb_08[mycolumns].mean(),mar_08[mycolumns].mean(),apr_08[mycolumns].mean(),may_08[mycolumns].mean(),jun_08[mycolumns].mean(),
        jul_08[mycolumns].mean(),aug_08[mycolumns].mean(),sep_08[mycolumns].mean(),oct_08[mycolumns].mean(),nov_08[mycolumns].mean(),dec_08[mycolumns].mean(),
        jan_09[mycolumns].mean(),feb_09[mycolumns].mean(),mar_09[mycolumns].mean(),apr_09[mycolumns].mean(),may_09[mycolumns].mean(),jun_09[mycolumns].mean(),
        jul_09[mycolumns].mean(),aug_09[mycolumns].mean(),sep_09[mycolumns].mean(),oct_09[mycolumns].mean(),nov_09[mycolumns].mean(),dec_09[mycolumns].mean(),
        jan_10[mycolumns].mean(),feb_10[mycolumns].mean(),mar_10[mycolumns].mean(),apr_10[mycolumns].mean(),may_10[mycolumns].mean(),jun_10[mycolumns].mean(),
        jul_10[mycolumns].mean(),aug_10[mycolumns].mean(),sep_10[mycolumns].mean(),oct_10[mycolumns].mean(),nov_10[mycolumns].mean(),dec_10[mycolumns].mean(),
        jan_11[mycolumns].mean(),feb_11[mycolumns].mean(),mar_11[mycolumns].mean(),apr_11[mycolumns].mean(),may_11[mycolumns].mean(),jun_11[mycolumns].mean(),
        jul_11[mycolumns].mean(),aug_11[mycolumns].mean(),sep_11[mycolumns].mean(),oct_11[mycolumns].mean(),nov_11[mycolumns].mean(),dec_11[mycolumns].mean(),
        jan_12[mycolumns].mean(),feb_12[mycolumns].mean(),mar_12[mycolumns].mean(),apr_12[mycolumns].mean(),may_12[mycolumns].mean(),jun_12[mycolumns].mean(),
        jul_12[mycolumns].mean(),aug_12[mycolumns].mean(),sep_12[mycolumns].mean(),oct_12[mycolumns].mean(),nov_12[mycolumns].mean(),dec_12[mycolumns].mean(),
        jan_13[mycolumns].mean(),feb_13[mycolumns].mean(),mar_13[mycolumns].mean(),apr_13[mycolumns].mean(),may_13[mycolumns].mean(),jun_13[mycolumns].mean(),
        jul_13[mycolumns].mean(),aug_13[mycolumns].mean(),sep_13[mycolumns].mean(),oct_13[mycolumns].mean(),nov_13[mycolumns].mean(),dec_13[mycolumns].mean(),
        jan_14[mycolumns].mean(),feb_14[mycolumns].mean(),mar_14[mycolumns].mean(),apr_14[mycolumns].mean(),may_14[mycolumns].mean(),jun_14[mycolumns].mean(),
        jul_14[mycolumns].mean(),aug_14[mycolumns].mean(),sep_14[mycolumns].mean(),oct_14[mycolumns].mean(),nov_14[mycolumns].mean(),dec_14[mycolumns].mean(),
        jan_15[mycolumns].mean(),feb_15[mycolumns].mean(),mar_15[mycolumns].mean(),apr_15[mycolumns].mean(),may_15[mycolumns].mean(),jun_15[mycolumns].mean(),
        jul_15[mycolumns].mean(),aug_15[mycolumns].mean(),sep_15[mycolumns].mean(),oct_15[mycolumns].mean(),nov_15[mycolumns].mean(),dec_15[mycolumns].mean(),
        jan_16[mycolumns].mean(),feb_16[mycolumns].mean(),mar_16[mycolumns].mean(),apr_16[mycolumns].mean(),may_16[mycolumns].mean(),jun_16[mycolumns].mean(),
        jul_16[mycolumns].mean(),aug_16[mycolumns].mean(),sep_16[mycolumns].mean(),oct_16[mycolumns].mean(),nov_16[mycolumns].mean(),dec_16[mycolumns].mean(),
        jan_17[mycolumns].mean(),feb_17[mycolumns].mean(),mar_17[mycolumns].mean(),apr_17[mycolumns].mean(),may_17[mycolumns].mean(),jun_17[mycolumns].mean(),
        jul_17[mycolumns].mean(),aug_17[mycolumns].mean(),sep_17[mycolumns].mean(),oct_17[mycolumns].mean(),nov_17[mycolumns].mean(),dec_17[mycolumns].mean(),
        jan_18[mycolumns].mean(),feb_18[mycolumns].mean(),mar_18[mycolumns].mean(),apr_18[mycolumns].mean(),may_18[mycolumns].mean(),jun_18[mycolumns].mean(),
        jul_18[mycolumns].mean(),aug_18[mycolumns].mean(),sep_18[mycolumns].mean(),oct_18[mycolumns].mean(),nov_18[mycolumns].mean(),dec_18[mycolumns].mean(),
        jan_19[mycolumns].mean(),feb_19[mycolumns].mean(),mar_19[mycolumns].mean(),apr_19[mycolumns].mean(),may_19[mycolumns].mean(),jun_19[mycolumns].mean(),
        jul_19[mycolumns].mean(),aug_19[mycolumns].mean(),sep_19[mycolumns].mean(),oct_19[mycolumns].mean(),nov_19[mycolumns].mean(),dec_19[mycolumns].mean(),
        jan_20[mycolumns].mean(),feb_20[mycolumns].mean(),mar_20[mycolumns].mean(),apr_20[mycolumns].mean(),may_20[mycolumns].mean(),jun_20[mycolumns].mean(),
        jul_20[mycolumns].mean(),aug_20[mycolumns].mean(),sep_20[mycolumns].mean(),oct_20[mycolumns].mean(),nov_20[mycolumns].mean(),dec_20[mycolumns].mean(),
        jan_21[mycolumns].mean(),feb_21[mycolumns].mean()]
#puts each of those values for each of the rows
for row in rows:
    df.loc[len(df)] = row
df.tail()
# Out:
#          Crude        Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  \
# 295  61.405479  441.747370      61.322860      62.092362   NaN
# 296  61.593493  442.694123      62.435777      63.095283   NaN
# 297  61.781507  443.640877      67.616060      67.383944   NaN
# 298  61.969521  444.587630      67.714243      67.110128   NaN
# 299  62.157534  445.534384      62.985577      62.446154   NaN
#
#      Urea_Pred_MLR(MLR)  Urea_Pred_MLR(RDF)  Urea_Pred_RDF(MLR)  \
# 295          287.547427          288.792636          313.099387
# 296          289.797725          290.864937          294.204146
# 297          298.629832          298.254221          271.986822
# 298          299.238085          298.260507          272.161095
# 299          292.035532          291.162638          288.069469
#
#      Urea_Pred_RDF(RDF)
# 295          286.386676
# 296          272.610335
# 297          272.061108
# 298          271.724943
# 299          298.100215

# %%
#creating monthly dates in datetime form from 1/1996 to 2/2021
from datetime import datetime
rng2 = pd.date_range(start='1996-01-01', periods=302, freq='M')
rng2
rng2 = pd.DataFrame(rng2)
df['Monthly_Date']= rng2

# %%
df
print(df.dtypes)
df.head()
# Out:
# Crude                        float64
# Corn                         float64
# Coal_RDF(MLR)                float64
# Coal_RDF(RDF)                float64
# Urea                         float64
# Urea_Pred_MLR(MLR)           float64
# Urea_Pred_MLR(RDF)           float64
# Urea_Pred_RDF(MLR)           float64
# Urea_Pred_RDF(RDF)           float64
# Monthly_Date          datetime64[ns]
# dtype: object
#      Crude      Corn  Coal_RDF(MLR)  Coal_RDF(RDF)    Urea  \
# 0  18.3100  365.3125      27.223602      27.223602  218.25
# 1  17.9025  376.0000      29.442748      29.442748  207.50
# 2  19.6040  385.7500      27.647682      27.647682  204.00
# 3  21.1725  443.6250      29.242930      29.242930  193.75
# 4  19.8240  450.5500      28.227713      28.227713  166.20
#
#    Urea_Pred_MLR(MLR)  Urea_Pred_MLR(RDF)  Urea_Pred_RDF(MLR)  \
# 0          149.973235          149.973235          206.289874
# 1          154.457894          154.457894          203.000223
# ...

# %%
#std dev of each of the different models
MLRMLR_upper = df['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Upper'] = MLRMLR_upper
MLRMLR_lower = df['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Lower'] = MLRMLR_lower

MLRRDF_upper = df['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Upper'] = MLRRDF_upper
MLRRDF_lower = df['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Lower'] = MLRRDF_lower

RDFMLR_upper = df['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Upper'] = RDFMLR_upper
RDFMLR_lower = df['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Lower'] = RDFMLR_lower

RDFRDF_upper = df['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Upper'] = RDFRDF_upper
RDFRDF_lower = df['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Lower'] = RDFRDF_lower

# %%
#looking at actual vs predicted monthly
import matplotlib.pyplot as plt
# %matplotlib inline

x = (df['Monthly_Date'])
y1 = (df['Urea'])
y2 = (df['Urea_Pred_MLR(MLR)'])
y3 = (df['Urea_Pred_MLR(RDF)'])
y4 = (df['Urea_Pred_RDF(MLR)'])
y5 = (df['Urea_Pred_RDF(RDF)'])
y6 = (df['MLR(MLR)Upper'])
y7 = (df['MLR(MLR)Lower'])
y8 = (df['MLR(RDF)Upper'])
y9 = (df['MLR(RDF)Lower'])
y10 = (df['RDF(MLR)Upper'])
y11 = (df['RDF(MLR)Lower'])
y12 = (df['RDF(RDF)Upper'])
y13 = (df['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Avg Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()

# %%
#now daily so not as smooth, but first find new std dev of all predicted models
#std dev of each of the different models
MLRMLR_upper2 = combined['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Upper'] = MLRMLR_upper2
MLRMLR_lower2 = combined['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Lower'] = MLRMLR_lower2

MLRRDF_upper2 = combined['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Upper'] = MLRRDF_upper2
MLRRDF_lower2 = combined['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Lower'] = MLRRDF_lower2

RDFMLR_upper2 = combined['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Upper'] = RDFMLR_upper2
RDFMLR_lower2 = combined['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Lower'] = RDFMLR_lower2

RDFRDF_upper2 = combined['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Upper'] = RDFRDF_upper2
RDFRDF_lower2 = combined['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Lower'] = RDFRDF_lower2

# %%
#looking at daily actual vs predicted
x = (combined['Date'])
y1 = (combined['Urea'])
y2 = (combined['Urea_Pred_MLR(MLR)'])
y3 = (combined['Urea_Pred_MLR(RDF)'])
y4 = (combined['Urea_Pred_RDF(MLR)'])
y5 = (combined['Urea_Pred_RDF(RDF)'])
y6 = (combined['MLR(MLR)Upper'])
y7 = (combined['MLR(MLR)Lower'])
y8 = (combined['MLR(RDF)Upper'])
y9 = (combined['MLR(RDF)Lower'])
y10 = (combined['RDF(MLR)Upper'])
y11 = (combined['RDF(MLR)Lower'])
y12 = (combined['RDF(RDF)Upper'])
y13 = (combined['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Avg Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()

# %% [markdown]
# # Urea Model Best Case

# %%
data = pd.read_csv("C:/Users/msteinme/Documents/ureamarchupdatebest2.csv")
df_96on = data[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea']][0:1056]
df_96on.tail()
# Out:
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea
# 1051  2/26/2016  34.58  359.50          50.45          50.45   265
# 1052   3/4/2016  37.75  358.25          51.00          51.00   270
# 1053  3/11/2016  40.09  365.00          51.50          51.50   274
# 1054  3/18/2016  41.14  371.75          52.20          52.20   265
# 1055  3/25/2016  40.63  374.50          51.75          51.75   255

# %%
from datetime import datetime
df_96on['Date'] = pd.to_datetime(df_96on['Date'])
date = df_96on['Date']
df_96on.dtypes
# Out:
# Date             datetime64[ns]
# Crude                   float64
# Corn                    float64
# Coal_RDF(MLR)           float64
# Coal_RDF(RDF)           float64
# Urea                    float64
# dtype: object

# %%
df_96on.describe()
# Out:
#              Crude         Corn  Coal_RDF(MLR)  Coal_RDF(RDF)         Urea
# count  1056.000000  1056.000000    1056.000000    1056.000000  1056.000000
# mean     54.851648   361.660275      58.312026      58.312026   260.121212
# std      31.319022   157.085607      33.658418      33.658418   135.997458
# min      11.260000   182.500000      20.900000      20.900000    83.000000
# 25%      26.402500   231.000000      27.425593      27.425593   150.750000
# 50%      49.655000   322.750000      51.925000      51.925000   240.000000
# 75%      82.082500   425.562500      80.175000      80.175000   335.000000
# max     145.860000   809.250000     192.500000     192.500000   825.000000

# %%
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
# Out:
# MSE train: 259.736, test: 1293.746
# R^2 train: 0.987, test: 0.916
# [ 0.55261487  0.10440454  0.34298058]

# %%
#comparing the different models
urea_predicted3 = forest.predict(X)
urea_predicted3 = pd.DataFrame(urea_predicted3)
df_96on['Urea_Pred_RDF(MLR)'] = urea_predicted3
rdf_error3 = (abs(df_96on['Urea_Pred_RDF(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error3

urea_predicted4 = forest.predict(X)
urea_predicted4 = pd.DataFrame(urea_predicted4)
df_96on['Urea_Pred_RDF(RDF)'] = urea_predicted4
rdf_error4 = (abs(df_96on['Urea_Pred_RDF(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error4

mlrtop3_predicted = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(MLR)']*1.6182) 
df_96on['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted
mlrtop3_error = (abs(df_96on['Urea_Pred_MLR(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(MLR)'] = mlrtop3_error

mlrtop3_predicted2 = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(RDF)']*1.6182) 
df_96on['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted2
mlrtop3_error2 = (abs(df_96on['Urea_Pred_MLR(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(RDF)'] = mlrtop3_error2

print("Average RDF(MLR) error is: %.3f" % (rdf_error3.mean())) 
print("Average RDF(RDF) error is: %.3f" % (rdf_error4.mean()))
print("Average MLR(MLR) Top3 error is: %.3f" % (mlrtop3_error.mean()))
print("Average MLR(RDF) Top3 error is: %.3f" % (mlrtop3_error2.mean()))

df_96on
# Out:
# Average RDF(MLR) error is: 5.280
# Average RDF(RDF) error is: 5.280
# Average MLR(MLR) Top3 error is: 16.762
# Average MLR(RDF) Top3 error is: 16.762
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  \
# 0    1996-01-05  19.65  369.75      25.358912      25.358912   220
# 1    1996-01-12  17.98  366.25      25.269689      25.269689   220
# 2    1996-01-19  18.25  365.00      29.070713      29.070713   218
# 3    1996-01-26  17.36  360.25      29.195096      29.195096   215
# 4    1996-02-02  17.38  370.50      32.105527      32.105527   205
# 5    1996-02-09  17.38  367.25      28.667889      28.667889   205
# 6    1996-02-16  18.40  382.75      28.169393      28.169393   210
# 7    1996-02-23  18.45  383.50      28.828182      28.828182   210
# 8    1996-03-01  18.62  386.75      27.863549      27.863549   210
# 9    1996-03-08  18.87  388.50      26.513218      26.513218   205
# 10   1996-03-15  20.08  383.25      27.863549      27.863549   205
# ...

# %%
newpred2 = data [['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']][1056:]
newpred = data [['Crude','Corn','Coal_RDF(MLR)']][1056:]
newpred3 = data[['Crude','Corn','Coal_RDF(RDF)']][1056:]

# %%
#new predictions
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)

newpred2 = np.array(newpred2)
newpred2 = pd.DataFrame(newpred2)
newpred2.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']
newpred_predicted = forest.predict(newpred)
df_new_pred = pd.DataFrame(newpred_predicted)
newpred2['Urea_Pred_RDF(MLR)'] = df_new_pred

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 252.378, test: 1252.954
# R^2 train: 0.987, test: 0.918
# [ 0.5769739   0.10118698  0.32183911]
#            Date    Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26    40.63   374.5       52.5251       52.5343
# 1    2016-03-27    40.63   374.5       52.5251       52.5343
# 2    2016-03-28    40.53   370.5       52.5421       53.4882
# 3    2016-03-29    39.51     373       52.9604        53.832
# 4    2016-03-30    39.66     367       53.1038       53.6404
# 5    2016-03-31    39.36   351.5        53.451       55.4772
# 6    2016-04-01  42.1429   378.5       52.6725       53.6984
# 7    2016-04-02  42.2857  378.85       52.6725       53.6984
# 8    2016-04-03  42.4286   379.2       52.7715       53.6984
# 9    2016-04-04  42.5714  379.55       52.9354        53.832
# 10   2016-04-05  42.7143   379.9       52.9354        53.832
# 11   2016-04-06  42.8571  380.25       52.9354        53.832
# 12   2016-04-07       43   380.6       52.9354        53.832
# ...

# %%
X = df_96on[['Crude','Corn','Coal_RDF(RDF)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
newpred_predicted2 = forest.predict(newpred3)
df_new_pred2 = pd.DataFrame(newpred_predicted2)
newpred2['Urea_Pred_RDF(RDF)'] = df_new_pred2

mlrtop3_predicted5 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(MLR)']*1.6182) 
newpred2['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted5

mlrtop3_predicted6 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(RDF)']*1.6182) 
newpred2['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted6

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 260.388, test: 1289.663
# R^2 train: 0.987, test: 0.916
# [ 0.56616999  0.10946648  0.32436353]
#            Date    Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26    40.63   374.5       52.5251       52.5343
# 1    2016-03-27    40.63   374.5       52.5251       52.5343
# 2    2016-03-28    40.53   370.5       52.5421       53.4882
# 3    2016-03-29    39.51     373       52.9604        53.832
# 4    2016-03-30    39.66     367       53.1038       53.6404
# 5    2016-03-31    39.36   351.5        53.451       55.4772
# 6    2016-04-01  42.1429   378.5       52.6725       53.6984
# 7    2016-04-02  42.2857  378.85       52.6725       53.6984
# 8    2016-04-03  42.4286   379.2       52.7715       53.6984
# 9    2016-04-04  42.5714  379.55       52.9354        53.832
# 10   2016-04-05  42.7143   379.9       52.9354        53.832
# 11   2016-04-06  42.8571  380.25       52.9354        53.832
# 12   2016-04-07       43   380.6       52.9354        53.832
# ...

# %%
frames = [df_96on,newpred2]
combined = pd.concat(frames)
combined
# Out:
#      Coal_RDF(MLR) Coal_RDF(RDF)    Corn    Crude       Date  MLR_Error(MLR)  \
# 0          25.3589       25.3589  369.75    19.65 1996-01-05       31.900057
# 1          25.2697       25.2697  366.25    17.98 1996-01-12       33.452854
# 2          29.0707       29.0707     365    18.25 1996-01-19       29.900320
# 3          29.1951       29.1951  360.25    17.36 1996-01-26       29.836261
# 4          32.1055       32.1055   370.5    17.38 1996-02-02       23.367129
# 5          28.6679       28.6679  367.25    17.38 1996-02-09       26.313098
# 6          28.1694       28.1694  382.75     18.4 1996-02-16       26.567275
# 7          28.8282       28.8282   383.5    18.45 1996-02-23       25.967943
# 8          27.8635       27.8635  386.75    18.62 1996-03-01       26.350656
# 9          26.5132       26.5132   388.5    18.87 1996-03-08       25.293638
# 10         27.8635       27.8635  383.25    20.08 1996-03-15       23.628148
# ...

# %%
combined.to_csv("C:/Users/msteinme/Documents/ureabestmarch2.csv")

# %%
#want to have obs continue from 0
combined = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']]
combined = np.array(combined)
combined = pd.DataFrame(combined)
combined.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
combined
# Out:
#                      Date    Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 0     1996-01-05 00:00:00    19.65  369.75       25.3589       25.3589  220
# 1     1996-01-12 00:00:00    17.98  366.25       25.2697       25.2697  220
# 2     1996-01-19 00:00:00    18.25     365       29.0707       29.0707  218
# 3     1996-01-26 00:00:00    17.36  360.25       29.1951       29.1951  215
# 4     1996-02-02 00:00:00    17.38   370.5       32.1055       32.1055  205
# 5     1996-02-09 00:00:00    17.38  367.25       28.6679       28.6679  205
# 6     1996-02-16 00:00:00     18.4  382.75       28.1694       28.1694  210
# 7     1996-02-23 00:00:00    18.45   383.5       28.8282       28.8282  210
# 8     1996-03-01 00:00:00    18.62  386.75       27.8635       27.8635  210
# 9     1996-03-08 00:00:00    18.87   388.5       26.5132       26.5132  205
# 10    1996-03-15 00:00:00    20.08  383.25       27.8635       27.8635  205
# ...

# %%
#monthly predictions remember 2 months in future so jan96->mar96
mar_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][0:4]
apr_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][4:8]
may_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][8:13]
jun_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][13:17]
jul_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][17:22]
aug_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][22:26]
sep_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][26:30]
oct_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][30:35]
nov_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][35:39]
dec_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][39:43]
jan_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][43:48]
feb_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][48:52]
mar_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][52:57]
apr_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][57:61]
may_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][61:65]
jun_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][65:69]
jul_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][69:74]
aug_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][74:78]
sep_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][78:82]
oct_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][82:87]
nov_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][87:91]
dec_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][91:96]
jan_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][96:100]
feb_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][100:104]
mar_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][104:109]
apr_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][109:113]
may_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][113:117]
jun_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][117:121]
jul_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][121:126]
aug_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][126:130]
sep_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][130:135]
oct_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][135:139]
nov_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][139:143]
dec_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][143:148]
jan_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][148:152]
feb_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][152:156]
mar_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][156:161]
apr_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][161:165]
may_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][165:169]
jun_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][169:174]
jul_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][174:178]
aug_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][178:182]
sep_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][182:187]
oct_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][187:191]
nov_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][191:195]
dec_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][195:200]
jan_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][200:204]
feb_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][204:209]
mar_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][209:213]
apr_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][213:217]
may_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][217:222]
jun_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][222:226]
jul_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][226:230]
aug_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][230:235]
sep_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][235:239]
oct_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][239:243]
nov_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][243:248]
dec_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][248:252]
jan_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][252:256]
feb_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][256:261]
mar_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][261:265]
apr_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][265:269]
may_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][269:274]
jun_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][274:278]
jul_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][278:282]
aug_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][282:287]
sep_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][287:291]
oct_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][291:296]
nov_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][296:300]
dec_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][300:304]
jan_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][304:309]
feb_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][309:313]
mar_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][313:317]
apr_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][317:321]
may_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][321:326]
jun_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][326:330]
jul_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][330:335]
aug_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][335:339]
sep_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][339:343]
oct_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][343:348]
nov_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][348:352]
dec_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][352:356]
jan_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][356:361]
feb_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][361:365]
mar_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][365:370]
apr_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][370:374]
may_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][374:378]
jun_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][378:382]
jul_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][382:387]
aug_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][387:391]
sep_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][391:395]
oct_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][395:400]
nov_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][400:404]
dec_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][404:409]
jan_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][409:413]
feb_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][413:417]
mar_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][417:422]
apr_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][422:426]
may_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][426:430]
jun_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][430:435]
jul_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][435:439]
aug_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][439:443]
sep_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][443:448]
oct_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][448:452]
nov_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][452:456]
dec_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][456:461]
jan_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][461:465]
feb_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][465:470]
mar_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][470:474]
apr_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][474:478]
may_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][478:482]
jun_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][482:487]
jul_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][487:491]
aug_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][491:495]
sep_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][495:500]
oct_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][500:504]
nov_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][504:509]
dec_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][509:513]
jan_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][513:517]
feb_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][517:522]
mar_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][522:526]
apr_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][526:530]
may_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][530:535]
jun_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][535:539]
jul_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][539:543]
aug_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][543:548]
sep_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][548:552]
oct_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][552:556]
nov_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][556:561]
dec_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][561:565]
jan_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][565:569]
feb_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][569:574]
mar_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][574:578]
apr_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][578:582]
may_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][582:587]
jun_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][587:591]
jul_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][591:595]
aug_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][595:600]
sep_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][600:604]
oct_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][604:609]
nov_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][609:613]
dec_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][613:617]
jan_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][617:622]
feb_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][622:626]
mar_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][626:630]
apr_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][630:635]
may_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][635:639]
jun_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][639:643]
jul_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][643:648]
aug_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][648:652]
sep_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][652:656]
oct_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][656:661]
nov_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][661:665]
dec_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][665:670]
jan_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][670:674]
feb_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][674:678]
mar_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][678:683]
apr_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][683:687]
may_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][687:691]
jun_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][691:695]
jul_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][695:700]
aug_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][700:704]
sep_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][704:709]
oct_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][709:713]
nov_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][713:717]
dec_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][717:722]
jan_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][722:726]
feb_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][726:730]
mar_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][730:735]
apr_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][735:739]
may_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][739:743]
jun_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][743:748]
jul_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][748:752]
aug_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][752:756]
sep_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][756:761]
oct_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][761:765]
nov_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][765:769]
dec_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][769:774]
jan_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][774:778]
feb_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][778:783]
mar_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][783:787]
apr_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][787:791]
may_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][791:795]
jun_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][795:800]
jul_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][800:804]
aug_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][804:808]
sep_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][808:813]
oct_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][813:817]
nov_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][817:822]
dec_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][822:826]
jan_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][826:830]
feb_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][830:835]
mar_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][835:839]
apr_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][839:843]
may_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][843:848]
jun_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][848:852]
jul_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][852:856]
aug_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][856:861]
sep_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][861:865]
oct_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][865:870]
nov_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][870:874]
dec_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][874:878]
jan_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][878:883]
feb_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][883:887]
mar_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][887:891]
apr_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][891:895]
may_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][895:900]
jun_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][900:904]
jul_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][904:909]
aug_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][909:913]
sep_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][913:917]
oct_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][917:922]
nov_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][922:926]
dec_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][926:930]
jan_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][930:935]
feb_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][935:939]
mar_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][939:944]
apr_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][944:948]
may_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][948:952]
jun_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][952:956]
jul_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][956:961]
aug_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][961:965]
sep_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][965:969]
oct_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][969:974]
nov_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][974:978]
dec_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][978:983]
jan_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][983:987]
feb_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][987:991]
mar_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][991:996]
apr_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][996:1000]
may_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1000:1004]
jun_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1004:1008]
jul_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1008:1013]
aug_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1013:1017]
sep_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1017:1022]
oct_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1022:1026]
nov_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1026:1030]
dec_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1030:1035]
jan_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1035:1039]
feb_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1039:1043]
mar_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1043:1048]
apr_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1048:1052]
may_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1052:1056]
apr_96
# Out:
#                   Date  Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 4  1996-02-02 00:00:00  17.38   370.5       32.1055       32.1055  205
# 5  1996-02-09 00:00:00  17.38  367.25       28.6679       28.6679  205
# 6  1996-02-16 00:00:00   18.4  382.75       28.1694       28.1694  210
# 7  1996-02-23 00:00:00  18.45   383.5       28.8282       28.8282  210
#
#   Urea_Pred_MLR(MLR) Urea_Pred_MLR(RDF) Urea_Pred_RDF(MLR) Urea_Pred_RDF(RDF)
# 4            157.097            157.097            200.846            200.846
# 5            151.058            151.058            200.587            200.587
# 6            154.209            154.209            199.055            199.055
# 7            155.467            155.467            201.317            201.317

# %%
# predicted chunk
jun_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1062:1092]
jul_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1092:1123]
aug_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1123:1153]
sep_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1153:1184]
oct_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1184:1215]
nov_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1215:1245]
dec_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1245:1276]
jan_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1276:1306]
feb_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1306:1337]
mar_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1337:1368]
apr_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1368:1396]
may_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1396:1427]
jun_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1427:1457]
jul_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1457:1488]
aug_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1488:1518]
sep_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1518:1549]
oct_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1549:1580]
nov_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1580:1610]
dec_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1610:1641]
jan_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1641:1671]
feb_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1671:1702]
mar_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1702:1733]
apr_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1733:1761]
may_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1761:1792]
jun_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1792:1822]
jul_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1822:1853]
aug_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1853:1883]
sep_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1883:1914]
oct_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1914:1945]
nov_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1945:1975]
dec_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1975:2006]
jan_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2006:2036]
feb_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2036:2067]
mar_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2067:2098]
apr_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2098:2126]
may_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2126:2157]
jun_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2157:2187]
jul_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2187:2218]
aug_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2218:2248]
sep_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2248:2279]
oct_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2279:2310]
nov_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2310:2340]
dec_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2340:2371]
jan_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2371:2401]
feb_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2401:2432]
mar_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2432:2463]
apr_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2463:2492]
may_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2492:2523]
jun_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2523:2553]
jul_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2553:2584]
aug_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2584:2614]
sep_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2614:2645]
oct_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2645:2676]
nov_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2676:2706]
dec_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2706:2737]
jan_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2737:2767]
feb_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2767:2798]

# %%
mycolumns = ['Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
df = pd.DataFrame(columns=mycolumns)
rows = [mar_96[mycolumns].mean(),apr_96[mycolumns].mean(),may_96[mycolumns].mean(),jun_96[mycolumns].mean(),
        jul_96[mycolumns].mean(),aug_96[mycolumns].mean(),sep_96[mycolumns].mean(),oct_96[mycolumns].mean(),nov_96[mycolumns].mean(),dec_96[mycolumns].mean(),
        jan_97[mycolumns].mean(),feb_97[mycolumns].mean(),mar_97[mycolumns].mean(),apr_97[mycolumns].mean(),may_97[mycolumns].mean(),jun_97[mycolumns].mean(),
        jul_97[mycolumns].mean(),aug_97[mycolumns].mean(),sep_97[mycolumns].mean(),oct_97[mycolumns].mean(),nov_97[mycolumns].mean(),dec_97[mycolumns].mean(),
        jan_98[mycolumns].mean(),feb_98[mycolumns].mean(),mar_98[mycolumns].mean(),apr_98[mycolumns].mean(),may_98[mycolumns].mean(),jun_98[mycolumns].mean(),
        jul_98[mycolumns].mean(),aug_98[mycolumns].mean(),sep_98[mycolumns].mean(),oct_98[mycolumns].mean(),nov_98[mycolumns].mean(),dec_98[mycolumns].mean(),
        jan_99[mycolumns].mean(),feb_99[mycolumns].mean(),mar_99[mycolumns].mean(),apr_99[mycolumns].mean(),may_99[mycolumns].mean(),jun_99[mycolumns].mean(),
        jul_99[mycolumns].mean(),aug_99[mycolumns].mean(),sep_99[mycolumns].mean(),oct_99[mycolumns].mean(),nov_99[mycolumns].mean(),dec_99[mycolumns].mean(),
        jan_00[mycolumns].mean(),feb_00[mycolumns].mean(),mar_00[mycolumns].mean(),apr_00[mycolumns].mean(),may_00[mycolumns].mean(),jun_00[mycolumns].mean(),
        jul_00[mycolumns].mean(),aug_00[mycolumns].mean(),sep_00[mycolumns].mean(),oct_00[mycolumns].mean(),nov_00[mycolumns].mean(),dec_00[mycolumns].mean(),
        jan_01[mycolumns].mean(),feb_01[mycolumns].mean(),mar_01[mycolumns].mean(),apr_01[mycolumns].mean(),may_01[mycolumns].mean(),jun_01[mycolumns].mean(),
        jul_01[mycolumns].mean(),aug_01[mycolumns].mean(),sep_01[mycolumns].mean(),oct_01[mycolumns].mean(),nov_01[mycolumns].mean(),dec_01[mycolumns].mean(),
        jan_02[mycolumns].mean(),feb_02[mycolumns].mean(),mar_02[mycolumns].mean(),apr_02[mycolumns].mean(),may_02[mycolumns].mean(),jun_02[mycolumns].mean(),
        jul_02[mycolumns].mean(),aug_02[mycolumns].mean(),sep_02[mycolumns].mean(),oct_02[mycolumns].mean(),nov_02[mycolumns].mean(),dec_02[mycolumns].mean(),
        jan_03[mycolumns].mean(),feb_03[mycolumns].mean(),mar_03[mycolumns].mean(),apr_03[mycolumns].mean(),may_03[mycolumns].mean(),jun_03[mycolumns].mean(),
        jul_03[mycolumns].mean(),aug_03[mycolumns].mean(),sep_03[mycolumns].mean(),oct_03[mycolumns].mean(),nov_03[mycolumns].mean(),dec_03[mycolumns].mean(),
        jan_04[mycolumns].mean(),feb_04[mycolumns].mean(),mar_04[mycolumns].mean(),apr_04[mycolumns].mean(),may_04[mycolumns].mean(),jun_04[mycolumns].mean(),
        jul_04[mycolumns].mean(),aug_04[mycolumns].mean(),sep_04[mycolumns].mean(),oct_04[mycolumns].mean(),nov_04[mycolumns].mean(),dec_04[mycolumns].mean(),
        jan_05[mycolumns].mean(),feb_05[mycolumns].mean(),mar_05[mycolumns].mean(),apr_05[mycolumns].mean(),may_05[mycolumns].mean(),jun_05[mycolumns].mean(),
        jul_05[mycolumns].mean(),aug_05[mycolumns].mean(),sep_05[mycolumns].mean(),oct_05[mycolumns].mean(),nov_05[mycolumns].mean(),dec_05[mycolumns].mean(),
        jan_06[mycolumns].mean(),feb_06[mycolumns].mean(),mar_06[mycolumns].mean(),apr_06[mycolumns].mean(),may_06[mycolumns].mean(),jun_06[mycolumns].mean(),
        jul_06[mycolumns].mean(),aug_06[mycolumns].mean(),sep_06[mycolumns].mean(),oct_06[mycolumns].mean(),nov_06[mycolumns].mean(),dec_06[mycolumns].mean(),
        jan_07[mycolumns].mean(),feb_07[mycolumns].mean(),mar_07[mycolumns].mean(),apr_07[mycolumns].mean(),may_07[mycolumns].mean(),jun_07[mycolumns].mean(),
        jul_07[mycolumns].mean(),aug_07[mycolumns].mean(),sep_07[mycolumns].mean(),oct_07[mycolumns].mean(),nov_07[mycolumns].mean(),dec_07[mycolumns].mean(),
        jan_08[mycolumns].mean(),feb_08[mycolumns].mean(),mar_08[mycolumns].mean(),apr_08[mycolumns].mean(),may_08[mycolumns].mean(),jun_08[mycolumns].mean(),
        jul_08[mycolumns].mean(),aug_08[mycolumns].mean(),sep_08[mycolumns].mean(),oct_08[mycolumns].mean(),nov_08[mycolumns].mean(),dec_08[mycolumns].mean(),
        jan_09[mycolumns].mean(),feb_09[mycolumns].mean(),mar_09[mycolumns].mean(),apr_09[mycolumns].mean(),may_09[mycolumns].mean(),jun_09[mycolumns].mean(),
        jul_09[mycolumns].mean(),aug_09[mycolumns].mean(),sep_09[mycolumns].mean(),oct_09[mycolumns].mean(),nov_09[mycolumns].mean(),dec_09[mycolumns].mean(),
        jan_10[mycolumns].mean(),feb_10[mycolumns].mean(),mar_10[mycolumns].mean(),apr_10[mycolumns].mean(),may_10[mycolumns].mean(),jun_10[mycolumns].mean(),
        jul_10[mycolumns].mean(),aug_10[mycolumns].mean(),sep_10[mycolumns].mean(),oct_10[mycolumns].mean(),nov_10[mycolumns].mean(),dec_10[mycolumns].mean(),
        jan_11[mycolumns].mean(),feb_11[mycolumns].mean(),mar_11[mycolumns].mean(),apr_11[mycolumns].mean(),may_11[mycolumns].mean(),jun_11[mycolumns].mean(),
        jul_11[mycolumns].mean(),aug_11[mycolumns].mean(),sep_11[mycolumns].mean(),oct_11[mycolumns].mean(),nov_11[mycolumns].mean(),dec_11[mycolumns].mean(),
        jan_12[mycolumns].mean(),feb_12[mycolumns].mean(),mar_12[mycolumns].mean(),apr_12[mycolumns].mean(),may_12[mycolumns].mean(),jun_12[mycolumns].mean(),
        jul_12[mycolumns].mean(),aug_12[mycolumns].mean(),sep_12[mycolumns].mean(),oct_12[mycolumns].mean(),nov_12[mycolumns].mean(),dec_12[mycolumns].mean(),
        jan_13[mycolumns].mean(),feb_13[mycolumns].mean(),mar_13[mycolumns].mean(),apr_13[mycolumns].mean(),may_13[mycolumns].mean(),jun_13[mycolumns].mean(),
        jul_13[mycolumns].mean(),aug_13[mycolumns].mean(),sep_13[mycolumns].mean(),oct_13[mycolumns].mean(),nov_13[mycolumns].mean(),dec_13[mycolumns].mean(),
        jan_14[mycolumns].mean(),feb_14[mycolumns].mean(),mar_14[mycolumns].mean(),apr_14[mycolumns].mean(),may_14[mycolumns].mean(),jun_14[mycolumns].mean(),
        jul_14[mycolumns].mean(),aug_14[mycolumns].mean(),sep_14[mycolumns].mean(),oct_14[mycolumns].mean(),nov_14[mycolumns].mean(),dec_14[mycolumns].mean(),
        jan_15[mycolumns].mean(),feb_15[mycolumns].mean(),mar_15[mycolumns].mean(),apr_15[mycolumns].mean(),may_15[mycolumns].mean(),jun_15[mycolumns].mean(),
        jul_15[mycolumns].mean(),aug_15[mycolumns].mean(),sep_15[mycolumns].mean(),oct_15[mycolumns].mean(),nov_15[mycolumns].mean(),dec_15[mycolumns].mean(),
        jan_16[mycolumns].mean(),feb_16[mycolumns].mean(),mar_16[mycolumns].mean(),apr_16[mycolumns].mean(),may_16[mycolumns].mean(),jun_16[mycolumns].mean(),
        jul_16[mycolumns].mean(),aug_16[mycolumns].mean(),sep_16[mycolumns].mean(),oct_16[mycolumns].mean(),nov_16[mycolumns].mean(),dec_16[mycolumns].mean(),
        jan_17[mycolumns].mean(),feb_17[mycolumns].mean(),mar_17[mycolumns].mean(),apr_17[mycolumns].mean(),may_17[mycolumns].mean(),jun_17[mycolumns].mean(),
        jul_17[mycolumns].mean(),aug_17[mycolumns].mean(),sep_17[mycolumns].mean(),oct_17[mycolumns].mean(),nov_17[mycolumns].mean(),dec_17[mycolumns].mean(),
        jan_18[mycolumns].mean(),feb_18[mycolumns].mean(),mar_18[mycolumns].mean(),apr_18[mycolumns].mean(),may_18[mycolumns].mean(),jun_18[mycolumns].mean(),
        jul_18[mycolumns].mean(),aug_18[mycolumns].mean(),sep_18[mycolumns].mean(),oct_18[mycolumns].mean(),nov_18[mycolumns].mean(),dec_18[mycolumns].mean(),
        jan_19[mycolumns].mean(),feb_19[mycolumns].mean(),mar_19[mycolumns].mean(),apr_19[mycolumns].mean(),may_19[mycolumns].mean(),jun_19[mycolumns].mean(),
        jul_19[mycolumns].mean(),aug_19[mycolumns].mean(),sep_19[mycolumns].mean(),oct_19[mycolumns].mean(),nov_19[mycolumns].mean(),dec_19[mycolumns].mean(),
        jan_20[mycolumns].mean(),feb_20[mycolumns].mean(),mar_20[mycolumns].mean(),apr_20[mycolumns].mean(),may_20[mycolumns].mean(),jun_20[mycolumns].mean(),
        jul_20[mycolumns].mean(),aug_20[mycolumns].mean(),sep_20[mycolumns].mean(),oct_20[mycolumns].mean(),nov_20[mycolumns].mean(),dec_20[mycolumns].mean(),
        jan_21[mycolumns].mean(),feb_21[mycolumns].mean()]
#puts each of those values for each of the rows
for row in rows:
    df.loc[len(df)] = row
df.tail()
# Out:
#          Crude  Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  Urea_Pred_MLR(MLR)  \
# 295  70.936986   500      69.617710      65.696614   NaN          325.255086
# 296  71.062329   500      60.773187      60.916749   NaN          311.149932
# 297  71.187671   500      54.163148      52.474836   NaN          300.660620
# 298  71.313014   500      52.839649      52.044962   NaN          298.725987
# 299  71.438356   500      51.875063      52.157542   NaN          297.372148
#
#      Urea_Pred_MLR(RDF)  Urea_Pred_RDF(MLR)  Urea_Pred_RDF(RDF)
# 295          318.909968          316.547852          324.194124
# 296          311.382245          334.766728          325.245768
# 297          297.928593          352.997210          332.092113
# 298          297.440025          332.810053          329.015508
# 299          297.829255          323.547083          330.074078

# %%
#creating monthly dates in datetime form from 1/1996 to 2/2021
from datetime import datetime
rng2 = pd.date_range(start='1996-01-01', periods=302, freq='M')
rng2
rng2 = pd.DataFrame(rng2)
df['Monthly_Date']= rng2

# %%
df
print(df.dtypes)
# Out:
# Crude                        float64
# Corn                         float64
# Coal_RDF(MLR)                float64
# Coal_RDF(RDF)                float64
# Urea                         float64
# Urea_Pred_MLR(MLR)           float64
# Urea_Pred_MLR(RDF)           float64
# Urea_Pred_RDF(MLR)           float64
# Urea_Pred_RDF(RDF)           float64
# Monthly_Date          datetime64[ns]
# dtype: object

# %%
#std dev of each of the different models, monthly
MLRMLR_upper = df['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Upper'] = MLRMLR_upper
MLRMLR_lower = df['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Lower'] = MLRMLR_lower

MLRRDF_upper = df['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Upper'] = MLRRDF_upper
MLRRDF_lower = df['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Lower'] = MLRRDF_lower

RDFMLR_upper = df['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Upper'] = RDFMLR_upper
RDFMLR_lower = df['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Lower'] = RDFMLR_lower

RDFRDF_upper = df['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Upper'] = RDFRDF_upper
RDFRDF_lower = df['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Lower'] = RDFRDF_lower

# %%
#looking at actual vs predicted monthly
import matplotlib.pyplot as plt
# %matplotlib inline

x = (df['Monthly_Date'])
y1 = (df['Urea'])
y2 = (df['Urea_Pred_MLR(MLR)'])
y3 = (df['Urea_Pred_MLR(RDF)'])
y4 = (df['Urea_Pred_RDF(MLR)'])
y5 = (df['Urea_Pred_RDF(RDF)'])
y6 = (df['MLR(MLR)Upper'])
y7 = (df['MLR(MLR)Lower'])
y8 = (df['MLR(RDF)Upper'])
y9 = (df['MLR(RDF)Lower'])
y10 = (df['RDF(MLR)Upper'])
y11 = (df['RDF(MLR)Lower'])
y12 = (df['RDF(RDF)Upper'])
y13 = (df['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Best Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()

# %%
#now daily so not as smooth, but first find new std dev of all predicted models
#std dev of each of the different models
MLRMLR_upper2 = combined['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Upper'] = MLRMLR_upper2
MLRMLR_lower2 = combined['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Lower'] = MLRMLR_lower2

MLRRDF_upper2 = combined['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Upper'] = MLRRDF_upper2
MLRRDF_lower2 = combined['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Lower'] = MLRRDF_lower2

RDFMLR_upper2 = combined['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Upper'] = RDFMLR_upper2
RDFMLR_lower2 = combined['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Lower'] = RDFMLR_lower2

RDFRDF_upper2 = combined['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Upper'] = RDFRDF_upper2
RDFRDF_lower2 = combined['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Lower'] = RDFRDF_lower2

# %%
#looking at daily actual vs predicted
x = (combined['Date'])
y1 = (combined['Urea'])
y2 = (combined['Urea_Pred_MLR(MLR)'])
y3 = (combined['Urea_Pred_MLR(RDF)'])
y4 = (combined['Urea_Pred_RDF(MLR)'])
y5 = (combined['Urea_Pred_RDF(RDF)'])
y6 = (combined['MLR(MLR)Upper'])
y7 = (combined['MLR(MLR)Lower'])
y8 = (combined['MLR(RDF)Upper'])
y9 = (combined['MLR(RDF)Lower'])
y10 = (combined['RDF(MLR)Upper'])
y11 = (combined['RDF(MLR)Lower'])
y12 = (combined['RDF(RDF)Upper'])
y13 = (combined['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Best Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()

# %% [markdown]
# # Urea Model Worst Case

# %%
data = pd.read_csv("C:/Users/msteinme/Documents/ureamarchupdateworst2.csv")
df_96on = data[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea']][0:1056]
df_96on.tail(2)
# Out:
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea
# 1054  3/18/2016  41.14  371.75          52.20          52.20   265
# 1055  3/25/2016  40.63  374.50          51.75          51.75   255

# %%
from datetime import datetime
df_96on['Date'] = pd.to_datetime(df_96on['Date'])
date = df_96on['Date']
df_96on.dtypes
# Out:
# Date             datetime64[ns]
# Crude                   float64
# Corn                    float64
# Coal_RDF(MLR)           float64
# Coal_RDF(RDF)           float64
# Urea                    float64
# dtype: object

# %%
df_96on.describe() #make sure both coal values the same
# Out:
#              Crude         Corn  Coal_RDF(MLR)  Coal_RDF(RDF)         Urea
# count  1056.000000  1056.000000    1056.000000    1056.000000  1056.000000
# mean     54.851648   361.660275      58.312026      58.312026   260.121212
# std      31.319022   157.085607      33.658418      33.658418   135.997458
# min      11.260000   182.500000      20.900000      20.900000    83.000000
# 25%      26.402500   231.000000      27.425593      27.425593   150.750000
# 50%      49.655000   322.750000      51.925000      51.925000   240.000000
# 75%      82.082500   425.562500      80.175000      80.175000   335.000000
# max     145.860000   809.250000     192.500000     192.500000   825.000000

# %%
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
# Out:
# MSE train: 243.048, test: 1299.225
# R^2 train: 0.988, test: 0.915
# [ 0.59248839  0.0913958   0.31611581]

# %%
#comparing the different models
urea_predicted3 = forest.predict(X)
urea_predicted3 = pd.DataFrame(urea_predicted3)
df_96on['Urea_Pred_RDF(MLR)'] = urea_predicted3
rdf_error3 = (abs(df_96on['Urea_Pred_RDF(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error3

urea_predicted4 = forest.predict(X)
urea_predicted4 = pd.DataFrame(urea_predicted4)
df_96on['Urea_Pred_RDF(RDF)'] = urea_predicted4
rdf_error4 = (abs(df_96on['Urea_Pred_RDF(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['RDF_Top3_Error(MLR)'] = rdf_error4

mlrtop3_predicted = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(MLR)']*1.6182) 
df_96on['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted
mlrtop3_error = (abs(df_96on['Urea_Pred_MLR(MLR)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(MLR)'] = mlrtop3_error

mlrtop3_predicted2 = 22.1189 + (df_96on['Crude']*1.6519) + (df_96on['Corn']*0.1466) + (df_96on['Coal_RDF(RDF)']*1.6182) 
df_96on['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted2
mlrtop3_error2 = (abs(df_96on['Urea_Pred_MLR(RDF)'] - df_96on['Urea'])/df_96on['Urea'])*100
df_96on['MLR_Error(RDF)'] = mlrtop3_error2

print("Average RDF(MLR) error is: %.3f" % (rdf_error3.mean())) 
print("Average RDF(RDF) error is: %.3f" % (rdf_error4.mean()))
print("Average MLR(MLR) Top3 error is: %.3f" % (mlrtop3_error.mean()))
print("Average MLR(RDF) Top3 error is: %.3f" % (mlrtop3_error2.mean()))

df_96on
# Out:
# Average RDF(MLR) error is: 5.275
# Average RDF(RDF) error is: 5.275
# Average MLR(MLR) Top3 error is: 16.762
# Average MLR(RDF) Top3 error is: 16.762
#            Date  Crude    Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  \
# 0    1996-01-05  19.65  369.75      25.358912      25.358912   220
# 1    1996-01-12  17.98  366.25      25.269689      25.269689   220
# 2    1996-01-19  18.25  365.00      29.070713      29.070713   218
# 3    1996-01-26  17.36  360.25      29.195096      29.195096   215
# 4    1996-02-02  17.38  370.50      32.105527      32.105527   205
# 5    1996-02-09  17.38  367.25      28.667889      28.667889   205
# 6    1996-02-16  18.40  382.75      28.169393      28.169393   210
# 7    1996-02-23  18.45  383.50      28.828182      28.828182   210
# 8    1996-03-01  18.62  386.75      27.863549      27.863549   210
# 9    1996-03-08  18.87  388.50      26.513218      26.513218   205
# 10   1996-03-15  20.08  383.25      27.863549      27.863549   205
# ...

# %%
newpred2 = data [['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']][1056:]
newpred = data [['Crude','Corn','Coal_RDF(MLR)']][1056:]
newpred3 = data[['Crude','Corn','Coal_RDF(RDF)']][1056:]

# %%
#new predictions
X = df_96on[['Crude','Corn','Coal_RDF(MLR)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)

newpred2 = np.array(newpred2)
newpred2 = pd.DataFrame(newpred2)
newpred2.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)']
newpred_predicted = forest.predict(newpred)
df_new_pred = pd.DataFrame(newpred_predicted)
newpred2['Urea_Pred_RDF(MLR)'] = df_new_pred

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 264.185, test: 1299.098
# R^2 train: 0.987, test: 0.915
# [ 0.5780628   0.09808667  0.32385053]
#            Date  Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26  40.63    374.5       52.2853       52.5426
# 1    2016-03-27  40.63    374.5       52.2853       52.5426
# 2    2016-03-28  40.53    370.5       52.2865       53.7917
# 3    2016-03-29  39.51      373       52.9085       54.9921
# 4    2016-03-30  39.66      367       53.0801       55.0984
# 5    2016-03-31  39.36    351.5       53.2868       58.1383
# 6    2016-04-01   38.3  368.857       52.0718       52.3235
# 7    2016-04-02   38.2  368.564       52.0718       52.2945
# 8    2016-04-03   38.1  368.271       51.8318       52.2922
# 9    2016-04-04   37.9  367.979       51.7373       52.3905
# 10   2016-04-05   37.8  367.686       51.8066       52.3905
# 11   2016-04-06   37.7  367.393       51.7209       52.3542
# 12   2016-04-07   37.6    367.1       51.4923       52.0274
# ...

# %%
X = df_96on[['Crude','Corn','Coal_RDF(RDF)']].values #coal_rdf(rdf) same as the mlr one but not later on in predicted sec
y = df_96on['Urea'].values
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=1)
forest=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
forest.fit(X_train, y_train)
y_train_pred= forest.predict(X_train)
y_test_pred= forest.predict(X_test)
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),r2_score(y_test,y_test_pred)))
print(forest.feature_importances_)
newpred_predicted2 = forest.predict(newpred3)
df_new_pred2 = pd.DataFrame(newpred_predicted2)
newpred2['Urea_Pred_RDF(RDF)'] = df_new_pred2

mlrtop3_predicted5 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(MLR)']*1.6182) 
newpred2['Urea_Pred_MLR(MLR)'] = mlrtop3_predicted5

mlrtop3_predicted6 = 22.1189 + (newpred2['Crude']*1.6519) + (newpred2['Corn']*0.1466) + (newpred2['Coal_RDF(RDF)']*1.6182) 
newpred2['Urea_Pred_MLR(RDF)'] = mlrtop3_predicted6

newpred2['Date'] = pd.to_datetime(newpred2['Date'])
newpred2
# Out:
# MSE train: 252.064, test: 1263.204
# R^2 train: 0.987, test: 0.918
# [ 0.56384246  0.09825952  0.33789802]
#            Date  Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF)  \
# 0    2016-03-26  40.63    374.5       52.2853       52.5426
# 1    2016-03-27  40.63    374.5       52.2853       52.5426
# 2    2016-03-28  40.53    370.5       52.2865       53.7917
# 3    2016-03-29  39.51      373       52.9085       54.9921
# 4    2016-03-30  39.66      367       53.0801       55.0984
# 5    2016-03-31  39.36    351.5       53.2868       58.1383
# 6    2016-04-01   38.3  368.857       52.0718       52.3235
# 7    2016-04-02   38.2  368.564       52.0718       52.2945
# 8    2016-04-03   38.1  368.271       51.8318       52.2922
# 9    2016-04-04   37.9  367.979       51.7373       52.3905
# 10   2016-04-05   37.8  367.686       51.8066       52.3905
# 11   2016-04-06   37.7  367.393       51.7209       52.3542
# 12   2016-04-07   37.6    367.1       51.4923       52.0274
# ...

# %%
frames = [df_96on,newpred2]
combined = pd.concat(frames)
combined
# Out:
#      Coal_RDF(MLR) Coal_RDF(RDF)     Corn  Crude       Date  MLR_Error(MLR)  \
# 0          25.3589       25.3589   369.75  19.65 1996-01-05       31.900057
# 1          25.2697       25.2697   366.25  17.98 1996-01-12       33.452854
# 2          29.0707       29.0707      365  18.25 1996-01-19       29.900320
# 3          29.1951       29.1951   360.25  17.36 1996-01-26       29.836261
# 4          32.1055       32.1055    370.5  17.38 1996-02-02       23.367129
# 5          28.6679       28.6679   367.25  17.38 1996-02-09       26.313098
# 6          28.1694       28.1694   382.75   18.4 1996-02-16       26.567275
# 7          28.8282       28.8282    383.5  18.45 1996-02-23       25.967943
# 8          27.8635       27.8635   386.75  18.62 1996-03-01       26.350656
# 9          26.5132       26.5132    388.5  18.87 1996-03-08       25.293638
# 10         27.8635       27.8635   383.25  20.08 1996-03-15       23.628148
# ...

# %%
combined.to_csv("C:/Users/msteinme/Documents/ureaworstmarch2.csv")

# %%
#want to have obs continue from 0
combined = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']]
combined = np.array(combined)
combined = pd.DataFrame(combined)
combined.columns = ['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
combined
# Out:
#                      Date  Crude     Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 0     1996-01-05 00:00:00  19.65   369.75       25.3589       25.3589  220
# 1     1996-01-12 00:00:00  17.98   366.25       25.2697       25.2697  220
# 2     1996-01-19 00:00:00  18.25      365       29.0707       29.0707  218
# 3     1996-01-26 00:00:00  17.36   360.25       29.1951       29.1951  215
# 4     1996-02-02 00:00:00  17.38    370.5       32.1055       32.1055  205
# 5     1996-02-09 00:00:00  17.38   367.25       28.6679       28.6679  205
# 6     1996-02-16 00:00:00   18.4   382.75       28.1694       28.1694  210
# 7     1996-02-23 00:00:00  18.45    383.5       28.8282       28.8282  210
# 8     1996-03-01 00:00:00  18.62   386.75       27.8635       27.8635  210
# 9     1996-03-08 00:00:00  18.87    388.5       26.5132       26.5132  205
# 10    1996-03-15 00:00:00  20.08   383.25       27.8635       27.8635  205
# ...

# %%
#monthly predictions remember 2 months in future so jan96->mar96
mar_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][0:4]
apr_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][4:8]
may_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][8:13]
jun_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][13:17]
jul_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][17:22]
aug_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][22:26]
sep_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][26:30]
oct_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][30:35]
nov_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][35:39]
dec_96 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][39:43]
jan_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][43:48]
feb_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][48:52]
mar_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][52:57]
apr_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][57:61]
may_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][61:65]
jun_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][65:69]
jul_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][69:74]
aug_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][74:78]
sep_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][78:82]
oct_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][82:87]
nov_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][87:91]
dec_97 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][91:96]
jan_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][96:100]
feb_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][100:104]
mar_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][104:109]
apr_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][109:113]
may_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][113:117]
jun_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][117:121]
jul_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][121:126]
aug_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][126:130]
sep_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][130:135]
oct_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][135:139]
nov_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][139:143]
dec_98 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][143:148]
jan_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][148:152]
feb_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][152:156]
mar_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][156:161]
apr_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][161:165]
may_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][165:169]
jun_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][169:174]
jul_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][174:178]
aug_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][178:182]
sep_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][182:187]
oct_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][187:191]
nov_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][191:195]
dec_99 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][195:200]
jan_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][200:204]
feb_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][204:209]
mar_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][209:213]
apr_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][213:217]
may_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][217:222]
jun_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][222:226]
jul_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][226:230]
aug_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][230:235]
sep_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][235:239]
oct_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][239:243]
nov_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][243:248]
dec_00 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][248:252]
jan_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][252:256]
feb_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][256:261]
mar_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][261:265]
apr_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][265:269]
may_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][269:274]
jun_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][274:278]
jul_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][278:282]
aug_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][282:287]
sep_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][287:291]
oct_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][291:296]
nov_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][296:300]
dec_01 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][300:304]
jan_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][304:309]
feb_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][309:313]
mar_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][313:317]
apr_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][317:321]
may_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][321:326]
jun_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][326:330]
jul_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][330:335]
aug_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][335:339]
sep_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][339:343]
oct_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][343:348]
nov_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][348:352]
dec_02 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][352:356]
jan_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][356:361]
feb_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][361:365]
mar_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][365:370]
apr_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][370:374]
may_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][374:378]
jun_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][378:382]
jul_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][382:387]
aug_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][387:391]
sep_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][391:395]
oct_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][395:400]
nov_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][400:404]
dec_03 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][404:409]
jan_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][409:413]
feb_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][413:417]
mar_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][417:422]
apr_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][422:426]
may_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][426:430]
jun_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][430:435]
jul_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][435:439]
aug_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][439:443]
sep_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][443:448]
oct_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][448:452]
nov_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][452:456]
dec_04 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][456:461]
jan_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][461:465]
feb_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][465:470]
mar_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][470:474]
apr_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][474:478]
may_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][478:482]
jun_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][482:487]
jul_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][487:491]
aug_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][491:495]
sep_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][495:500]
oct_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][500:504]
nov_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][504:509]
dec_05 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][509:513]
jan_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][513:517]
feb_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][517:522]
mar_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][522:526]
apr_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][526:530]
may_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][530:535]
jun_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][535:539]
jul_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][539:543]
aug_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][543:548]
sep_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][548:552]
oct_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][552:556]
nov_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][556:561]
dec_06 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][561:565]
jan_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][565:569]
feb_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][569:574]
mar_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][574:578]
apr_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][578:582]
may_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][582:587]
jun_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][587:591]
jul_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][591:595]
aug_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][595:600]
sep_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][600:604]
oct_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][604:609]
nov_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][609:613]
dec_07 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][613:617]
jan_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][617:622]
feb_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][622:626]
mar_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][626:630]
apr_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][630:635]
may_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][635:639]
jun_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][639:643]
jul_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][643:648]
aug_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][648:652]
sep_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][652:656]
oct_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][656:661]
nov_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][661:665]
dec_08 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][665:670]
jan_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][670:674]
feb_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][674:678]
mar_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][678:683]
apr_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][683:687]
may_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][687:691]
jun_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][691:695]
jul_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][695:700]
aug_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][700:704]
sep_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][704:709]
oct_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][709:713]
nov_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][713:717]
dec_09 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][717:722]
jan_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][722:726]
feb_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][726:730]
mar_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][730:735]
apr_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][735:739]
may_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][739:743]
jun_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][743:748]
jul_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][748:752]
aug_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][752:756]
sep_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][756:761]
oct_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][761:765]
nov_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][765:769]
dec_10 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][769:774]
jan_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][774:778]
feb_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][778:783]
mar_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][783:787]
apr_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][787:791]
may_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][791:795]
jun_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][795:800]
jul_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][800:804]
aug_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][804:808]
sep_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][808:813]
oct_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][813:817]
nov_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][817:822]
dec_11 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][822:826]
jan_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][826:830]
feb_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][830:835]
mar_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][835:839]
apr_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][839:843]
may_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][843:848]
jun_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][848:852]
jul_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][852:856]
aug_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][856:861]
sep_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][861:865]
oct_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][865:870]
nov_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][870:874]
dec_12 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][874:878]
jan_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][878:883]
feb_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][883:887]
mar_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][887:891]
apr_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][891:895]
may_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][895:900]
jun_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][900:904]
jul_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][904:909]
aug_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][909:913]
sep_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][913:917]
oct_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][917:922]
nov_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][922:926]
dec_13 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][926:930]
jan_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][930:935]
feb_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][935:939]
mar_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][939:944]
apr_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][944:948]
may_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][948:952]
jun_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][952:956]
jul_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][956:961]
aug_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][961:965]
sep_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][965:969]
oct_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][969:974]
nov_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][974:978]
dec_14 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][978:983]
jan_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][983:987]
feb_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][987:991]
mar_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][991:996]
apr_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][996:1000]
may_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1000:1004]
jun_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1004:1008]
jul_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1008:1013]
aug_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1013:1017]
sep_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1017:1022]
oct_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1022:1026]
nov_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1026:1030]
dec_15 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1030:1035]
jan_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1035:1039]
feb_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1039:1043]
mar_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1043:1048]
apr_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1048:1052]
may_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1052:1056]
apr_96
# Out:
#                   Date  Crude    Corn Coal_RDF(MLR) Coal_RDF(RDF) Urea  \
# 4  1996-02-02 00:00:00  17.38   370.5       32.1055       32.1055  205
# 5  1996-02-09 00:00:00  17.38  367.25       28.6679       28.6679  205
# 6  1996-02-16 00:00:00   18.4  382.75       28.1694       28.1694  210
# 7  1996-02-23 00:00:00  18.45   383.5       28.8282       28.8282  210
#
#   Urea_Pred_MLR(MLR) Urea_Pred_MLR(RDF) Urea_Pred_RDF(MLR) Urea_Pred_RDF(RDF)
# 4            157.097            157.097             200.91             200.91
# 5            151.058            151.058            200.154            200.154
# 6            154.209            154.209             200.59             200.59
# 7            155.467            155.467            201.534            201.534

# %%
# predicted chunk
jun_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1062:1092]
jul_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1092:1123]
aug_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1123:1153]
sep_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1153:1184]
oct_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1184:1215]
nov_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1215:1245]
dec_16 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1245:1276]
jan_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1276:1306]
feb_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1306:1337]
mar_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1337:1368]
apr_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1368:1396]
may_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1396:1427]
jun_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1427:1457]
jul_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1457:1488]
aug_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1488:1518]
sep_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1518:1549]
oct_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1549:1580]
nov_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1580:1610]
dec_17 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1610:1641]
jan_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1641:1671]
feb_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1671:1702]
mar_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1702:1733]
apr_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1733:1761]
may_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1761:1792]
jun_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1792:1822]
jul_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1822:1853]
aug_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1853:1883]
sep_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1883:1914]
oct_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1914:1945]
nov_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1945:1975]
dec_18 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][1975:2006]
jan_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2006:2036]
feb_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2036:2067]
mar_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2067:2098]
apr_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2098:2126]
may_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2126:2157]
jun_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2157:2187]
jul_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2187:2218]
aug_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2218:2248]
sep_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2248:2279]
oct_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2279:2310]
nov_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2310:2340]
dec_19 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2340:2371]
jan_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2371:2401]
feb_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2401:2432]
mar_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2432:2463]
apr_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2463:2492]
may_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2492:2523]
jun_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2523:2553]
jul_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2553:2584]
aug_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2584:2614]
sep_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2614:2645]
oct_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2645:2676]
nov_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2676:2706]
dec_20 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2706:2737]
jan_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2737:2767]
feb_21 = combined[['Date','Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']][2767:2798]

# %%
mycolumns = ['Crude','Corn','Coal_RDF(MLR)','Coal_RDF(RDF)','Urea','Urea_Pred_MLR(MLR)','Urea_Pred_MLR(RDF)','Urea_Pred_RDF(MLR)','Urea_Pred_RDF(RDF)']
df = pd.DataFrame(columns=mycolumns)
rows = [mar_96[mycolumns].mean(),apr_96[mycolumns].mean(),may_96[mycolumns].mean(),jun_96[mycolumns].mean(),
        jul_96[mycolumns].mean(),aug_96[mycolumns].mean(),sep_96[mycolumns].mean(),oct_96[mycolumns].mean(),nov_96[mycolumns].mean(),dec_96[mycolumns].mean(),
        jan_97[mycolumns].mean(),feb_97[mycolumns].mean(),mar_97[mycolumns].mean(),apr_97[mycolumns].mean(),may_97[mycolumns].mean(),jun_97[mycolumns].mean(),
        jul_97[mycolumns].mean(),aug_97[mycolumns].mean(),sep_97[mycolumns].mean(),oct_97[mycolumns].mean(),nov_97[mycolumns].mean(),dec_97[mycolumns].mean(),
        jan_98[mycolumns].mean(),feb_98[mycolumns].mean(),mar_98[mycolumns].mean(),apr_98[mycolumns].mean(),may_98[mycolumns].mean(),jun_98[mycolumns].mean(),
        jul_98[mycolumns].mean(),aug_98[mycolumns].mean(),sep_98[mycolumns].mean(),oct_98[mycolumns].mean(),nov_98[mycolumns].mean(),dec_98[mycolumns].mean(),
        jan_99[mycolumns].mean(),feb_99[mycolumns].mean(),mar_99[mycolumns].mean(),apr_99[mycolumns].mean(),may_99[mycolumns].mean(),jun_99[mycolumns].mean(),
        jul_99[mycolumns].mean(),aug_99[mycolumns].mean(),sep_99[mycolumns].mean(),oct_99[mycolumns].mean(),nov_99[mycolumns].mean(),dec_99[mycolumns].mean(),
        jan_00[mycolumns].mean(),feb_00[mycolumns].mean(),mar_00[mycolumns].mean(),apr_00[mycolumns].mean(),may_00[mycolumns].mean(),jun_00[mycolumns].mean(),
        jul_00[mycolumns].mean(),aug_00[mycolumns].mean(),sep_00[mycolumns].mean(),oct_00[mycolumns].mean(),nov_00[mycolumns].mean(),dec_00[mycolumns].mean(),
        jan_01[mycolumns].mean(),feb_01[mycolumns].mean(),mar_01[mycolumns].mean(),apr_01[mycolumns].mean(),may_01[mycolumns].mean(),jun_01[mycolumns].mean(),
        jul_01[mycolumns].mean(),aug_01[mycolumns].mean(),sep_01[mycolumns].mean(),oct_01[mycolumns].mean(),nov_01[mycolumns].mean(),dec_01[mycolumns].mean(),
        jan_02[mycolumns].mean(),feb_02[mycolumns].mean(),mar_02[mycolumns].mean(),apr_02[mycolumns].mean(),may_02[mycolumns].mean(),jun_02[mycolumns].mean(),
        jul_02[mycolumns].mean(),aug_02[mycolumns].mean(),sep_02[mycolumns].mean(),oct_02[mycolumns].mean(),nov_02[mycolumns].mean(),dec_02[mycolumns].mean(),
        jan_03[mycolumns].mean(),feb_03[mycolumns].mean(),mar_03[mycolumns].mean(),apr_03[mycolumns].mean(),may_03[mycolumns].mean(),jun_03[mycolumns].mean(),
        jul_03[mycolumns].mean(),aug_03[mycolumns].mean(),sep_03[mycolumns].mean(),oct_03[mycolumns].mean(),nov_03[mycolumns].mean(),dec_03[mycolumns].mean(),
        jan_04[mycolumns].mean(),feb_04[mycolumns].mean(),mar_04[mycolumns].mean(),apr_04[mycolumns].mean(),may_04[mycolumns].mean(),jun_04[mycolumns].mean(),
        jul_04[mycolumns].mean(),aug_04[mycolumns].mean(),sep_04[mycolumns].mean(),oct_04[mycolumns].mean(),nov_04[mycolumns].mean(),dec_04[mycolumns].mean(),
        jan_05[mycolumns].mean(),feb_05[mycolumns].mean(),mar_05[mycolumns].mean(),apr_05[mycolumns].mean(),may_05[mycolumns].mean(),jun_05[mycolumns].mean(),
        jul_05[mycolumns].mean(),aug_05[mycolumns].mean(),sep_05[mycolumns].mean(),oct_05[mycolumns].mean(),nov_05[mycolumns].mean(),dec_05[mycolumns].mean(),
        jan_06[mycolumns].mean(),feb_06[mycolumns].mean(),mar_06[mycolumns].mean(),apr_06[mycolumns].mean(),may_06[mycolumns].mean(),jun_06[mycolumns].mean(),
        jul_06[mycolumns].mean(),aug_06[mycolumns].mean(),sep_06[mycolumns].mean(),oct_06[mycolumns].mean(),nov_06[mycolumns].mean(),dec_06[mycolumns].mean(),
        jan_07[mycolumns].mean(),feb_07[mycolumns].mean(),mar_07[mycolumns].mean(),apr_07[mycolumns].mean(),may_07[mycolumns].mean(),jun_07[mycolumns].mean(),
        jul_07[mycolumns].mean(),aug_07[mycolumns].mean(),sep_07[mycolumns].mean(),oct_07[mycolumns].mean(),nov_07[mycolumns].mean(),dec_07[mycolumns].mean(),
        jan_08[mycolumns].mean(),feb_08[mycolumns].mean(),mar_08[mycolumns].mean(),apr_08[mycolumns].mean(),may_08[mycolumns].mean(),jun_08[mycolumns].mean(),
        jul_08[mycolumns].mean(),aug_08[mycolumns].mean(),sep_08[mycolumns].mean(),oct_08[mycolumns].mean(),nov_08[mycolumns].mean(),dec_08[mycolumns].mean(),
        jan_09[mycolumns].mean(),feb_09[mycolumns].mean(),mar_09[mycolumns].mean(),apr_09[mycolumns].mean(),may_09[mycolumns].mean(),jun_09[mycolumns].mean(),
        jul_09[mycolumns].mean(),aug_09[mycolumns].mean(),sep_09[mycolumns].mean(),oct_09[mycolumns].mean(),nov_09[mycolumns].mean(),dec_09[mycolumns].mean(),
        jan_10[mycolumns].mean(),feb_10[mycolumns].mean(),mar_10[mycolumns].mean(),apr_10[mycolumns].mean(),may_10[mycolumns].mean(),jun_10[mycolumns].mean(),
        jul_10[mycolumns].mean(),aug_10[mycolumns].mean(),sep_10[mycolumns].mean(),oct_10[mycolumns].mean(),nov_10[mycolumns].mean(),dec_10[mycolumns].mean(),
        jan_11[mycolumns].mean(),feb_11[mycolumns].mean(),mar_11[mycolumns].mean(),apr_11[mycolumns].mean(),may_11[mycolumns].mean(),jun_11[mycolumns].mean(),
        jul_11[mycolumns].mean(),aug_11[mycolumns].mean(),sep_11[mycolumns].mean(),oct_11[mycolumns].mean(),nov_11[mycolumns].mean(),dec_11[mycolumns].mean(),
        jan_12[mycolumns].mean(),feb_12[mycolumns].mean(),mar_12[mycolumns].mean(),apr_12[mycolumns].mean(),may_12[mycolumns].mean(),jun_12[mycolumns].mean(),
        jul_12[mycolumns].mean(),aug_12[mycolumns].mean(),sep_12[mycolumns].mean(),oct_12[mycolumns].mean(),nov_12[mycolumns].mean(),dec_12[mycolumns].mean(),
        jan_13[mycolumns].mean(),feb_13[mycolumns].mean(),mar_13[mycolumns].mean(),apr_13[mycolumns].mean(),may_13[mycolumns].mean(),jun_13[mycolumns].mean(),
        jul_13[mycolumns].mean(),aug_13[mycolumns].mean(),sep_13[mycolumns].mean(),oct_13[mycolumns].mean(),nov_13[mycolumns].mean(),dec_13[mycolumns].mean(),
        jan_14[mycolumns].mean(),feb_14[mycolumns].mean(),mar_14[mycolumns].mean(),apr_14[mycolumns].mean(),may_14[mycolumns].mean(),jun_14[mycolumns].mean(),
        jul_14[mycolumns].mean(),aug_14[mycolumns].mean(),sep_14[mycolumns].mean(),oct_14[mycolumns].mean(),nov_14[mycolumns].mean(),dec_14[mycolumns].mean(),
        jan_15[mycolumns].mean(),feb_15[mycolumns].mean(),mar_15[mycolumns].mean(),apr_15[mycolumns].mean(),may_15[mycolumns].mean(),jun_15[mycolumns].mean(),
        jul_15[mycolumns].mean(),aug_15[mycolumns].mean(),sep_15[mycolumns].mean(),oct_15[mycolumns].mean(),nov_15[mycolumns].mean(),dec_15[mycolumns].mean(),
        jan_16[mycolumns].mean(),feb_16[mycolumns].mean(),mar_16[mycolumns].mean(),apr_16[mycolumns].mean(),may_16[mycolumns].mean(),jun_16[mycolumns].mean(),
        jul_16[mycolumns].mean(),aug_16[mycolumns].mean(),sep_16[mycolumns].mean(),oct_16[mycolumns].mean(),nov_16[mycolumns].mean(),dec_16[mycolumns].mean(),
        jan_17[mycolumns].mean(),feb_17[mycolumns].mean(),mar_17[mycolumns].mean(),apr_17[mycolumns].mean(),may_17[mycolumns].mean(),jun_17[mycolumns].mean(),
        jul_17[mycolumns].mean(),aug_17[mycolumns].mean(),sep_17[mycolumns].mean(),oct_17[mycolumns].mean(),nov_17[mycolumns].mean(),dec_17[mycolumns].mean(),
        jan_18[mycolumns].mean(),feb_18[mycolumns].mean(),mar_18[mycolumns].mean(),apr_18[mycolumns].mean(),may_18[mycolumns].mean(),jun_18[mycolumns].mean(),
        jul_18[mycolumns].mean(),aug_18[mycolumns].mean(),sep_18[mycolumns].mean(),oct_18[mycolumns].mean(),nov_18[mycolumns].mean(),dec_18[mycolumns].mean(),
        jan_19[mycolumns].mean(),feb_19[mycolumns].mean(),mar_19[mycolumns].mean(),apr_19[mycolumns].mean(),may_19[mycolumns].mean(),jun_19[mycolumns].mean(),
        jul_19[mycolumns].mean(),aug_19[mycolumns].mean(),sep_19[mycolumns].mean(),oct_19[mycolumns].mean(),nov_19[mycolumns].mean(),dec_19[mycolumns].mean(),
        jan_20[mycolumns].mean(),feb_20[mycolumns].mean(),mar_20[mycolumns].mean(),apr_20[mycolumns].mean(),may_20[mycolumns].mean(),jun_20[mycolumns].mean(),
        jul_20[mycolumns].mean(),aug_20[mycolumns].mean(),sep_20[mycolumns].mean(),oct_20[mycolumns].mean(),nov_20[mycolumns].mean(),dec_20[mycolumns].mean(),
        jan_21[mycolumns].mean(),feb_21[mycolumns].mean()]
#puts each of those values for each of the rows
for row in rows:
    df.loc[len(df)] = row
df.tail()
# Out:
#          Crude        Corn  Coal_RDF(MLR)  Coal_RDF(RDF)  Urea  \
# 295  45.000000  407.739726      52.947593      57.920552   NaN
# 296  45.666667  410.246575      53.566113      58.068531   NaN
# 297  46.332258  412.753425      53.625795      58.068531   NaN
# 298  47.003333  415.260274      53.884070      58.041631   NaN
# 299  47.670968  417.767123      53.999231      58.247921   NaN
#
#      Urea_Pred_MLR(MLR)  Urea_Pred_MLR(RDF)  Urea_Pred_RDF(MLR)  \
# 295          241.908839          249.956082          267.691569
# 296          244.378499          251.664311          269.182344
# 297          245.942071          253.131306          290.516945
# 298          247.836065          254.563829          297.394826
# 299          249.492788          256.368018          302.396664
#
#      Urea_Pred_RDF(RDF)
# 295          262.730825
# 296          264.006039
# 297          287.717395
# 298          295.286396
# 299          300.027576

# %%
#creating monthly dates in datetime form from 1/1996 to 2/2021
from datetime import datetime
rng2 = pd.date_range(start='1996-01-01', periods=302, freq='M')
rng2
rng2 = pd.DataFrame(rng2)
df['Monthly_Date']= rng2

# %%
print(df.dtypes)
# Out:
# Crude                        float64
# Corn                         float64
# Coal_RDF(MLR)                float64
# Coal_RDF(RDF)                float64
# Urea                         float64
# Urea_Pred_MLR(MLR)           float64
# Urea_Pred_MLR(RDF)           float64
# Urea_Pred_RDF(MLR)           float64
# Urea_Pred_RDF(RDF)           float64
# Monthly_Date          datetime64[ns]
# dtype: object

# %%
#std dev of each of the different models, monthly
MLRMLR_upper = df['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Upper'] = MLRMLR_upper
MLRMLR_lower = df['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
df['MLR(MLR)Lower'] = MLRMLR_lower

MLRRDF_upper = df['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Upper'] = MLRRDF_upper
MLRRDF_lower = df['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
df['MLR(RDF)Lower'] = MLRRDF_lower

RDFMLR_upper = df['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Upper'] = RDFMLR_upper
RDFMLR_lower = df['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
df['RDF(MLR)Lower'] = RDFMLR_lower

RDFRDF_upper = df['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Upper'] = RDFRDF_upper
RDFRDF_lower = df['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
df['RDF(RDF)Lower'] = RDFRDF_lower

# %%
#looking at actual vs predicted monthly
import matplotlib.pyplot as plt
# %matplotlib inline

x = (df['Monthly_Date'])
y1 = (df['Urea'])
y2 = (df['Urea_Pred_MLR(MLR)'])
y3 = (df['Urea_Pred_MLR(RDF)'])
y4 = (df['Urea_Pred_RDF(MLR)'])
y5 = (df['Urea_Pred_RDF(RDF)'])
y6 = (df['MLR(MLR)Upper'])
y7 = (df['MLR(MLR)Lower'])
y8 = (df['MLR(RDF)Upper'])
y9 = (df['MLR(RDF)Lower'])
y10 = (df['RDF(MLR)Upper'])
y11 = (df['RDF(MLR)Lower'])
y12 = (df['RDF(RDF)Upper'])
y13 = (df['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Worst Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()

# %%
#now daily so not as smooth, but first find new std dev of all predicted models
#std dev of each of the different models
MLRMLR_upper2 = combined['Urea_Pred_MLR(MLR)'] + combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Upper'] = MLRMLR_upper2
MLRMLR_lower2 = combined['Urea_Pred_MLR(MLR)'] - combined['Urea_Pred_MLR(MLR)'].std()
combined['MLR(MLR)Lower'] = MLRMLR_lower2

MLRRDF_upper2 = combined['Urea_Pred_MLR(RDF)'] + combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Upper'] = MLRRDF_upper2
MLRRDF_lower2 = combined['Urea_Pred_MLR(RDF)'] - combined['Urea_Pred_MLR(RDF)'].std()
combined['MLR(RDF)Lower'] = MLRRDF_lower2

RDFMLR_upper2 = combined['Urea_Pred_RDF(MLR)'] + combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Upper'] = RDFMLR_upper2
RDFMLR_lower2 = combined['Urea_Pred_RDF(MLR)'] - combined['Urea_Pred_RDF(MLR)'].std()
combined['RDF(MLR)Lower'] = RDFMLR_lower2

RDFRDF_upper2 = combined['Urea_Pred_RDF(RDF)'] + combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Upper'] = RDFRDF_upper2
RDFRDF_lower2 = combined['Urea_Pred_RDF(RDF)'] - combined['Urea_Pred_RDF(RDF)'].std()
combined['RDF(RDF)Lower'] = RDFRDF_lower2

# %%
#looking at daily actual vs predicted
x = (combined['Date'])
y1 = (combined['Urea'])
y2 = (combined['Urea_Pred_MLR(MLR)'])
y3 = (combined['Urea_Pred_MLR(RDF)'])
y4 = (combined['Urea_Pred_RDF(MLR)'])
y5 = (combined['Urea_Pred_RDF(RDF)'])
y6 = (combined['MLR(MLR)Upper'])
y7 = (combined['MLR(MLR)Lower'])
y8 = (combined['MLR(RDF)Upper'])
y9 = (combined['MLR(RDF)Lower'])
y10 = (combined['RDF(MLR)Upper'])
y11 = (combined['RDF(MLR)Lower'])
y12 = (combined['RDF(RDF)Upper'])
y13 = (combined['RDF(RDF)Lower'])
fig = plt.figure(figsize=(18,12))
ax = fig.add_subplot(111)
ax.plot(x,y1,'r')
#ax.plot(x,y2,'g')
#ax.plot(x,y3,'b')
#ax.plot(x,y4,'m')
ax.plot(x,y5,'k')
#ax.plot(x,y6,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y7,'g--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y8,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y9,'b--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y10,'m--',dashes=(2,5),alpha=0.3)
#ax.plot(x,y11,'m--',dashes=(2,5),alpha=0.3)
ax.plot(x,y12,'k--',dashes=(2,5),alpha=0.3)
ax.plot(x,y13,'k--',dashes=(2,5),alpha=0.3)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)
ax.set_title('Actual vs Predicted (Worst Case)', size=(30))
ax.tick_params(axis='x',which='major',labelsize=15)
ax.tick_params(axis='y',which='major',labelsize=15)
ax.set_ylabel('Urea Price',size=(20))
plt.show()
